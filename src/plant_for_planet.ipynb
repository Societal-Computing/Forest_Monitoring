# %% [markdown]
# ### Projects Meta Data

# %%
# the file downloaded from planet websites https://app.plant-for-the-planet.org/app/projects?_scope=map&currency=EUR&tenant=ten_NxJq55pm&filter[purpose]=trees,conservation&locale=en
import pandas as pd
import json
import requests
import ast
from shapely.geometry import shape, Polygon, MultiPolygon,mapping
from shapely.ops import transform
import pyproj
import numpy as np
from scipy import stats
from shapely import wkt
import geopandas as gpd

from helper_functions import remove_not_geom, count_all_polygons, split_multipolygon, convert_3d_to_2d

# %% [markdown]
# # Retrieve website information

# %%
df=pd.read_csv("../input/Plant_for_planet_shapefiles/plantforplanet_projects.csv")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
projects_dict = df.groupby('properties.id').apply(lambda x: x.drop('properties.id', axis=1).to_dict(orient='records')).to_dict()
projects_dict
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# /var/folders/_l/gj90rjl90fngb4_8ph5x5jhc0000gn/T/ipykernel_29774/1013981461.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   projects_dict = df.groupby('properties.id').apply(lambda x: x.drop('properties.id', axis=1).to_dict(orient='records')).to_dict()
# {'proj_08KPr5UC3XliXwWgDqNgiIHs': [{'Unnamed: 0': 65,
#    'type': 'Feature',
#    'geometry.type': 'Point',
#    'geometry.coordinates': '[40.739686581322246, -2.317548419577491]',
#    'properties._scope': 'map',
#    'properties.allowDonations': True,
#    'properties.classification': 'large-scale-planting',
#    'properties.countPlanted': 813710.0,
#    'properties.countTarget': 1800000.0,
#    'properties.country': 'KE',
#    'properties.currency': 'EUR',
#    'properties.fixedRates': '[]',
#    'properties.image': '631bb1e028d86881019932.jpg',
#    'properties.isApproved': True,
#    'properties.isFeatured': False,
#    'properties.isPublished': True,
#    'properties.isTopProject': True,
#    'properties.location': 'Kenya',
#    'properties.minTreeCount': 2.0,
#    'properties.name': 'Eden Reforestation Projects - Kenya',
#    'properties.paymentDefaults.fixedTreeCountOptions': '[10, 25, 50, 100]',
#    'properties.paymentDefaults.fixedDefaultTreeCount': 5.0,
#    'properties.purpose': 'trees',
#    'properties.reviewScore': 0,
#    'properties.reviews': "[{'pdf': '6453caf8eb5b9155030400.pdf', 'id': 'prev_6c8pMIt7r3aM', 'issueMonth': '02-2023'}]",
#    'properties.slug': 'eden-reforestation-projects-kenya',
#    'properties.taxDeductionCountries': "['DE', 'US', 'ES']",
#    'properties.tpo.image': '5cae3e3395e52084699403.jpeg',
#    'properties.tpo.address.zipCode': '91741',
#    'properties.tpo.address.country': 'US',
#    'properties.tpo.address.address': '303 W Foothill Blvd. Unit 13',
#    'properties.tpo.address.city': 'Glendora',
#    'properties.tpo.name': 'Eden Reforestation Projects',
#    'properties.tpo.id': 'tpo_4DeNcQv0Dn8bFAm12PlY8zec',
#    'properties.tpo.email': 'info@edenprojects.org',
#    'properties.tpo.slug': 'eden-reforestation-projects',
#    'properties.treeCost': 0.14,
#    'properties.unitCost': 0.14,
#    'properties.description': nan,
#    'properties.metadata.degradationCause': nan,
#    'properties.metadata.longTermPlan': nan,
#    'properties.metadata.mainChallenge': nan,
#    'properties.metadata.motivation': nan,
#    'properties.options': '[]',
#    'properties.paymentDefaults': nan,
#    'properties.fixedRates.CHF': nan,
#    'properties.metadata.actions': nan,
#    'properties.metadata.benefits': nan,
#    'properties.metadata.coBenefits': nan,
#    'properties.metadata.ecologicalBenefits': nan,
#    'properties.metadata.socialBenefits': nan}],
#  'proj_0A74ghLQsx842038zk8fEQC9': [{'Unnamed: 0': 185,
#    'type': 'Feature',
#    'geometry.type': 'Point',
#    'geometry.coordinates': '[-121.87668888889, 44.70088195308]',
#    'properties._scope': 'map',
#    'properties.allowDonations': False,
#    'properties.classification': 'large-scale-planting',
#    'properties.countPlanted': 130000.0,
#    'properties.countTarget': 130000.0,
#    'properties.country': 'US',
#    'properties.currency': 'EUR',
#    'properties.fixedRates': '[]',
#    'properties.image': '5f4e6fe383dd4031999357.jpeg',
#    'properties.isApproved': False,
#    'properties.isFeatured': False,
#    'properties.isPublished': True,
#    'properties.isTopProject': False,
#    'properties.location': '44°42\'3.175"N 121°52\'36.08"W',
#    'properties.minTreeCount': 1.0,
#    'properties.name': 'Willamette National Forest',
#    'properties.paymentDefaults.fixedTreeCountOptions': '[1, 1, 1, 1]',
#    'properties.paymentDefaults.fixedDefaultTreeCount': 1.0,
#    'properties.purpose': 'trees',
#    'properties.reviewScore': 0,
#    'properties.reviews': '[]',
#    'properties.slug': 'willamette-national-forest',
#    'properties.taxDeductionCountries': "['DE', 'US', 'ES']",
#    'properties.tpo.image': '5e453a816329e302431983.jpeg',
#    'properties.tpo.address.zipCode': '59804-7212',
#    'properties.tpo.address.country': 'US',
#    'properties.tpo.address.address': 'Fort Missoula Road, Bldg. 27, Suite 3',
#    'properties.tpo.address.city': 'Missoula, Montana',
#    'properties.tpo.name': 'National Forest Foundation',
#    'properties.tpo.id': 'tpo_auG8xE1tt3slOnLQDelCdU16',
#    'properties.tpo.email': 'dwallien@nationalforests.org',
#    'properties.tpo.slug': 'national-forest-foundation',
#    'properties.treeCost': 0.95,
#    'properties.unitCost': 0.95,
#    'properties.description': nan,
#    'properties.metadata.degradationCause': nan,
#    'properties.metadata.longTermPlan': nan,
#    'properties.metadata.mainChallenge': nan,
#    'properties.metadata.motivation': nan,
#    'properties.options': '[]',
#    'properties.paymentDefaults': nan,
#    'properties.fixedRates.CHF': nan,
#    'properties.metadata.actions': nan,
#    'properties.metadata.benefits': nan,
#    'properties.metadata.coBenefits': nan,
#    'properties.metadata.ecologicalBenefits': nan,
#    'properties.metadata.socialBenefits': nan}],
#  'proj_0CgTQJMm5zX624sdpVDet93O': [{'Unnamed: 0': 233,
#    'type': 'Feature',
#    'geometry.type': 'Point',
#    'geometry.coordinates': '[-3.6127996718743, 37.184999918231]',
#    'properties._scope': 'map',
#    'properties.allowDonations': True,
#    'properties.classification': 'large-scale-planting',
#    'properties.countPlanted': 25155.0,
#    'properties.countTarget': 200000.0,
#    'properties.country': 'ES',
#    'properties.currency': 'EUR',
#    'properties.fixedRates': '[]',
#    'properties.image': '5fb8060f3e369590072652.jpg',
#    'properties.isApproved': False,
#    'properties.isFeatured': True,
#    'properties.isPublished': True,
#    'properties.isTopProject': False,
#    'properties.location': 'Granada, Spain',
#    'properties.minTreeCount': 2.0,
#    'properties.name': 'Anillo Verde de Granada - Phase I',
#    'properties.paymentDefaults.fixedTreeCountOptions': '[10, 25, 50, 100]',
#    'properties.paymentDefaults.fixedDefaultTreeCount': 5.0,
#    'properties.purpose': 'trees',
#    'properties.reviewScore': 0,
#    'properties.reviews': '[]',
#    'properties.slug': 'reunion-anillo-verde-de-granada-phase-i',
#    'properties.taxDeductionCountries': "['DE', 'ES', 'US']",
#    'properties.tpo.image': nan,
#    'properties.tpo.address.zipCode': '08015',
#    'properties.tpo.address.country': 'ES',
#    'properties.tpo.address.address': 'Diputació, 119-121, 3-2',
#    'properties.tpo.address.city': 'Barcelona',
#    'properties.tpo.name': 'Plant-for-the-Planet Spain Foundation',
#    'properties.tpo.id': 'tpo_hIje0zxERUTkGhBwyYBuGG2G',
#    'properties.tpo.email': 'info@planetspain.org',
#    'properties.tpo.slug': 'plant-for-the-planet-spain-foundation',
#    'properties.treeCost': 9.0,
#    'properties.unitCost': 9.0,
#    'properties.description': nan,
#    'properties.metadata.degradationCause': nan,
#    'properties.metadata.longTermPlan': nan,
#    'properties.metadata.mainChallenge': nan,
#    'properties.metadata.motivation': nan,
#    'properties.options': '[]',
#    'properties.paymentDefaults': nan,
#    'properties.fixedRates.CHF': nan,
#    'properties.metadata.actions': nan,
#    'properties.metadata.benefits': nan,
#    'properties.metadata.coBenefits': nan,
#    'properties.metadata.ecologicalBenefits': nan,
#    'properties.metadata.socialBenefits': nan}],
#  'proj_1Kf3YBRtxY7puQhuMms94MlA': [{'Unnamed: 0': 5,
#    'type': 'Feature',
#    'geometry.type': 'Point',
#    'geometry.coordinates': '[33.12409, 3.6103933999611]',
#    'properties._scope': 'map',
#    'properties.allowDonations': False,
#    'properties.classification': 'managed-regeneration',
#    'properties.countPlanted': 63943.0,
#    'properties.countTarget': 120000.0,
#    'properties.country': 'UG',
#    'properties.currency': 'EUR',
#    'properties.fixedRates': '[]',
#    'properties.image': '5fe24729c05b4955256074.jpeg',
#    'properties.isApproved': False,
#    'properties.isFeatured': False,
#    'properties.isPublished': True,
#    'properties.isTopProject': False,
#    'properties.location': 'Madi Opei, Kitgum District, Uganda',
#    'properties.minTreeCount': 1.0,
#    'properties.name': 'Magic to Uganda II',
#    'properties.paymentDefaults.fixedTreeCountOptions': '[1, 1, 1, 1]',
#    'properties.paymentDefaults.fixedDefaultTreeCount': 1.0,
#    'properties.purpose': 'trees',
#    'properties.reviewScore': 0,
#    'properties.reviews': '[]',
#    'properties.slug': 'magic-to-uganda-ii',
#    'properties.taxDeductionCountries': "['DE', 'US', 'ES']",
#    'properties.tpo.image': '60b62d20e0b43439805777.png',
#    'properties.tpo.address.zipCode': '74348',
#    'properties.tpo.address.country': 'DE',
#    'properties.tpo.address.address': 'Siedlerstr. 13',
#    'properties.tpo.address.city': 'Lauffen',
#    'properties.tpo.name': 'Magic to the World e.V.',
#    'properties.tpo.id': 'tpo_ft9253KsSBrp9VfJ0YOGLWwW',
#    'properties.tpo.email': 'magictotheworld@gmail.com',
#    'properties.tpo.slug': 'magic-to-the-world-e-v',
#    'properties.treeCost': 0.4,
#    'properties.unitCost': 0.4,
#    'properties.description': nan,
#    'properties.metadata.degradationCause': nan,
#    'properties.metadata.longTermPlan': nan,
#    'properties.metadata.mainChallenge': nan,
#    'properties.metadata.motivation': nan,
#    'properties.options': '[]',
#    'properties.paymentDefaults': nan,
#    'properties.fixedRates.CHF': nan,
#    'properties.metadata.actions': nan,
#    'properties.metadata.benefits': nan,
#    'properties.metadata.coBenefits': nan,
#    'properties.metadata.ecologicalBenefits': nan,
#    'properties.metadata.socialBenefits': nan}],
#  'proj_1fYkuEszMqU7ryjrlEhqpkdA': [{'Unnamed: 0': 6,
#    'type': 'Feature',
#    'geometry.type': 'Point',
#    'geometry.coordinates': '[35.0, -18.382160204996]',
#    'properties._scope': 'map',
#    'properties.allowDonations': True,
#    'properties.classification': 'mangroves',
#    'properties.countPlanted': 533976.0,
#    'properties.countTarget': 10000000.0,
#    'properties.country': 'MZ',
#    'properties.currency': 'EUR',
#    'properties.fixedRates': '[]',
#    'properties.image': '5f7de54941c95283741207.jpeg',
#    'properties.isApproved': False,
#    'properties.isFeatured': False,
#    'properties.isPublished': True,
#    'properties.isTopProject': False,
#    'properties.location': 'Mozambique',
#    'properties.minTreeCount': 2.0,
#    'properties.name': 'Eden Reforestation Projects - Djabissa, Mozambique',
#    'properties.paymentDefaults.fixedTreeCountOptions': '[10, 25, 50, 100]',
#    'properties.paymentDefaults.fixedDefaultTreeCount': 5.0,
#    'properties.purpose': 'trees',
#    'properties.reviewScore': 0,
#    'properties.reviews': '[]',
#    'properties.slug': 'eden-reforestation-projects-mozambique',
#    'properties.taxDeductionCountries': "['DE', 'US', 'ES']",
#    'properties.tpo.image': '5cae3e3395e52084699403.jpeg',
#    'properties.tpo.address.zipCode': '91741',
#    'properties.tpo.address.country': 'US',
#    'properties.tpo.address.address': '303 W Foothill Blvd. Unit 13',
#    'properties.tpo.address.city': 'Glendora',
#    'properties.tpo.name': 'Eden Reforestation Projects',
#    'properties.tpo.id': 'tpo_4DeNcQv0Dn8bFAm12PlY8zec',
#    'properties.tpo.email': 'info@edenprojects.org',
#    'properties.tpo.slug': 'eden-reforestation-projects',
#    'properties.treeCost': 0.14,
#    'properties.unitCost': 0.14,
#    'properties.description': nan,
#    'properties.metadata.degradationCause': nan,
#    'properties.metadata.longTermPlan': nan,
#    'properties.metadata.mainChallenge': nan,
#    'properties.metadata.motivation': nan,
#    'properties.options': '[]',
#    'properties.paymentDefaults': nan,
#    'properties.fixedRates.CHF': nan,
#    'properties.metadata.actions': nan,
#    'properties.metadata.benefits': nan,
#    'properties.metadata.coBenefits': nan,
#    'properties.metadata.ecologicalBenefits': nan,
#    'properties.metadata.socialBenefits': nan}],
#  'proj_1y4M0K04UnCHkUc3u1W31ZDJ': [{'Unnamed: 0': 157,
#    'type': 'Feature',
#    'geometry.type': 'Point',
#    'geometry.coordinates': '[24.532084928552, -28.528660285738]',
#    'properties._scope': 'map',
#    'properties.allowDonations': True,
#    'properties.classification': 'natural-regeneration',
#    'properties.countPlanted': 254.0,
#    'properties.countTarget': 5000000.0,
#    'properties.country': 'ZA',
#    'properties.currency': 'EUR',
#    'properties.fixedRates': '[]',
#    'properties.image': '5e79f89b529f3215972288.png',
#    'properties.isApproved': False,
#    'properties.isFeatured': False,
#    'properties.isPublished': True,
#    'properties.isTopProject': False,
#    'properties.location': 'Barkley West, South Africa',
#    'properties.minTreeCount': 1.0,
#    'properties.name': '5MTrees',
#    'properties.paymentDefaults.fixedTreeCountOptions': '[25, 50, 100, 500]',
#    'properties.paymentDefaults.fixedDefaultTreeCount': 10.0,
#    'properties.purpose': 'trees',
#    'properties.reviewScore': 0,
#    'properties.reviews': '[]',
#    'properties.slug': '5mtrees',
#    'properties.taxDeductionCountries': "['DE', 'US', 'ES']",
#    'properties.tpo.image': '5e7cd26f317cc020526722.png',
#    'properties.tpo.address.zipCode': '8375',
#    'properties.tpo.address.country': 'ZA',
#    'properties.tpo.address.address': '6 Short Street, Barkley West',
#    'properties.tpo.address.city': 'Barkley West',
#    'properties.tpo.name': 'LLB Africa',
#    'properties.tpo.id': 'tpo_AX00eohh7jljikdtAhHaVv82',
#    'properties.tpo.email': 'kwasi@llbafrica.org.za',
#    'properties.tpo.slug': 'llb-africa',
#    'properties.treeCost': 4.22,
#    'properties.unitCost': 4.22,
#    'properties.description': nan,
#    'properties.metadata.degradationCause': nan,
#    'properties.metadata.longTermPlan': nan,
#    'properties.metadata.mainChallenge': nan,
#    'properties.metadata.motivation': nan,
#    'properties.options': '[]',
#    'properties.paymentDefaults': nan,
#    'properties.fixedRates.CHF': nan,
#    'properties.metadata.actions': nan,
#    'properties.metadata.benefits': nan,
#    'properties.metadata.coBenefits': nan,
#    'properties.metadata.ecologicalBenefits': nan,
#    'properties.metadata.socialBenefits': nan}],
#  'proj_26OP7JiC5mapekmJ4OahxzD8': [{'Unnamed: 0': 205,
#    'type': 'Feature',
#    'geometry.type': 'Point',
#    'geometry.coordinates': '[32.335706651, 1.5156142533981]',
#    'properties._scope': 'map',
#    'properties.allowDonations': True,
#    'properties.classification': 'large-scale-planting',
#    'properties.countPlanted': 38609.0,
#    'properties.countTarget': 250000.0,
#    'properties.country': 'UG',
#    'properties.currency': 'EUR',
#    'properties.fixedRates': '[]',
#    'properties.image': '5f1ff2256e1c9891993694.jpeg',
#    'properties.isApproved': False,
#    'properties.isFeatured': False,
#    'properties.isPublished': True,
#    'properties.isTopProject': False,
#    'properties.location': 'Sub-Saharan Africa',
#    'properties.minTreeCount': 1.0,
#    'properties.name': 'Sustainable Community Forestry Programme',
#    'properties.paymentDefaults.fixedTreeCountOptions': '[1, 1, 1, 1]',
#    'properties.paymentDefaults.fixedDefaultTreeCount': 1.0,
#    'properties.purpose': 'trees',
#    'properties.reviewScore': 0,
#    'properties.reviews': '[]',
#    'properties.slug': 'sustainable-community-forestry-programme',
#    'properties.taxDeductionCountries': "['DE', 'US', 'ES']",
#    'properties.tpo.image': '5e6795d1eb849871705147.png',
#    'properties.tpo.address.zipCode': 'OX4 1JE',
#    'properties.tpo.address.country': 'GB',
#    'properties.tpo.address.address': '106-108 Cowley Road',
#    'properties.tpo.address.city': 'Oxford',
#    'properties.tpo.name': 'International Tree Foundation',
#    'properties.tpo.id': 'tpo_bb6W3HHcMDlIrDthOOkRAI1U',
#    'properties.tpo.email': 'info@internationaltreefoundation.org',
#    'properties.tpo.slug': 'international-tree-foundation',
#    'properties.treeCost': 4.21,
#    'properties.unitCost': 4.21,
#    'properties.description': nan,
#    'properties.metadata.degradationCause': nan,
#    'properties.metadata.longTermPlan': nan,
#    'properties.metadata.mainChallenge': nan,
#    'properties.metadata.motivation': nan,
#    'properties.options': '[]',
#    'properties.paymentDefaults': nan,
#    'properties.fixedRates.CHF': nan,
#    'properties.metadata.actions': nan,
#    'properties.metadata.benefits': nan,
#    'properties.metadata.coBenefits': nan,
#    'properties.metadata.ecologicalBenefits': nan,
#    'properties.metadata.socialBenefits': nan}],
#  'proj_2DvPGB3vj6HiPRjer3hqYYst': [{'Unnamed: 0': 135,
#    'type': 'Feature',
#    'geometry.type': 'Point',
#    'geometry.coordinates': '[-75.375586, 6.697111]',
#    'properties._scope': 'map',
#    'properties.allowDonations': True,
#    'properties.classification': 'natural-regeneration',
#    'properties.countPlanted': 70.0,
#    'properties.countTarget': 7000.0,
#    'properties.country': 'CO',
#    'properties.currency': 'EUR',
#    'properties.fixedRates': '[]',
#    'properties.image': '60a3a98866d8e341316653.JPG',
#    'properties.isApproved': False,
#    'properties.isFeatured': False,
#    'properties.isPublished': True,
#    'properties.isTopProject': False,
#    'properties.location': 'Guanacas Reserve, Colombia',
#    'properties.minTreeCount': 1.0,
#    'properties.name': 'Restoring the Andean cloud forest at the Guanacas Reserve',
#    'properties.paymentDefaults.fixedTreeCountOptions': '[10, 25, 50, 100]',
#    'properties.paymentDefaults.fixedDefaultTreeCount': 5.0,
#    'properties.purpose': 'trees',
#    'properties.reviewScore': 0,
#    'properties.reviews': '[]',
#    'properties.slug': 'restoring-the-andean-cloud-forest-at-the-guanacas-reserve',
#    'properties.taxDeductionCountries': "['DE', 'US', 'ES']",
#    'properties.tpo.image': '60bf8864787f6476060474.png',
#    'properties.tpo.address.zipCode': '050021',
#    'properties.tpo.address.country': 'CO',
#    'properties.tpo.address.address': 'Calle 5 A # 43 A- 73',
#    'properties.tpo.address.city': 'medellin',
#    'properties.tpo.name': 'Fundacion Guanacas',
#    'properties.tpo.id': 'tpo_B4giGGAuxsJ7wNNQUK0MvZHt',
#    'properties.tpo.email': 'maria.moreno@fundacionguanacas.org',
#    'properties.tpo.slug': 'fundacion-guanacas',
#    'properties.treeCost': 15.0,
#    'properties.unitCost': 15.0,
#    'properties.description': nan,
#    'properties.metadata.degradationCause': nan,
#    'properties.metadata.longTermPlan': nan,
#    'properties.metadata.mainChallenge': nan,
#    'properties.metadata.motivation': nan,
#    'properties.options': '[]',
#    'properties.paymentDefaults': nan,
#    'properties.fixedRates.CHF': nan,
#    'properties.metadata.actions': nan,
#    'properties.metadata.benefits': nan,
#    'properties.metadata.coBenefits': nan,
#    'properties.metadata.ecologicalBenefits': nan,
#    'properties.metadata.socialBenefits': nan}],
#  'proj_2FmGOs7knVISP7WauXnluJsG': [{'Unnamed: 0': 72,
#    'type': 'Feature',
#    'geometry.type': 'Point',
#    'geometry.coordinates': '[-123.67423443873, 41.091728921823]',
#    'properties._scope': 'map',
#    'properties.allowDonations': False,
#    'properties.classification': 'large-scale-planting',
#    'properties.countPlanted': 62000.0,
#    'properties.countTarget': 62000.0,
#    'properties.country': 'US',
#    'properties.currency': 'EUR',
#    'properties.fixedRates': '[]',
#    'properties.image': '615ec0764eb69236161933.jpg',
#    'properties.isApproved': False,
#    'properties.isFeatured': False,
#    'properties.isPublished': True,
#    'properties.isTopProject': False,
#    'properties.location': nan,
#    'properties.minTreeCount': 1.0,
#    'properties.name': 'California 2022 - Red-Salmon Fire Restoration',
#    'properties.paymentDefaults.fixedTreeCountOptions': '[10, 25, 50, 100]',
#    'properties.paymentDefaults.fixedDefaultTreeCount': 5.0,
#    'properties.purpose': 'trees',
#    'properties.reviewScore': 0,
#    'properties.reviews': '[]',
#    'properties.slug': 'red-salmon',
#    'properties.taxDeductionCountries': "['DE', 'US', 'ES']",
#    'properties.tpo.image': '5ee3bd84c8d35124875069.png',
#    'properties.tpo.address.zipCode': '05482',
#    'properties.tpo.address.country': 'US',
#    'properties.tpo.address.address': '145 Pine Haven Shores Road, Suite 1000D',
#    'properties.tpo.address.city': 'Shelburne',
#    'properties.tpo.name': 'One Tree Planted',
#    'properties.tpo.id': 'tpo_XaEjbTfMh5rfOhVf7646jdpP',
#    'properties.tpo.email': 'projectsplatforms@onetreeplanted.org',
#    'properties.tpo.slug': 'one-tree-planted',
#    'properties.treeCost': 1.18,
#    'properties.unitCost': 1.18,
#    'properties.description': nan,
#    'properties.metadata.degradationCause': nan,
#    'properties.metadata.longTermPlan': nan,
#    'properties.metadata.mainChallenge': nan,
#    'properties.metadata.motivation': nan,
#    'properties.options': '[]',
#    'properties.paymentDefaults': nan,
#    'properties.fixedRates.CHF': nan,
#    'properties.metadata.actions': nan,
#    'properties.metadata.benefits': nan,
#    'properties.metadata.coBenefits': nan,
#    'properties.metadata.ecologicalBenefits': nan,
#    'properties.metadata.socialBenefits': nan}],
#  'proj_2Mbjnwzzq87GyqlQYZ3RuyVC': [{'Unnamed: 0': 168,
#    'type': 'Feature',
#    'geometry.type': 'Point',
#    'geometry.coordinates': '[2.180655, 48.965216]',
#    'properties._scope': 'map',
#    'properties.allowDonations': False,
#    'properties.classification': 'urban-planting',
#    'properties.countPlanted': 7200.0,
#    'properties.countTarget': 7200.0,
#    'properties.country': 'FR',
#    'properties.currency': 'EUR',
#    'properties.fixedRates': '[]',
#    'properties.image': '61e5d38853e95361551393.jpg',
#    'properties.isApproved': False,
#    'properties.isFeatured': False,
#    'properties.isPublished': True,
#    'properties.isTopProject': False,
#    'properties.location': nan,
#    'properties.minTreeCount': 0.0,
#    'properties.name': 'France 2022 - Salesforce Trees for a Changing Climate',
#    'properties.paymentDefaults.fixedTreeCountOptions': '[0, 0, 0, 0]',
#    'properties.paymentDefaults.fixedDefaultTreeCount': 0.0,
#    'properties.purpose': 'trees',
#    'properties.reviewScore': 0,
#    'properties.reviews': '[]',
#    'properties.slug': 'france-salesforce',
#    'properties.taxDeductionCountries': "['DE', 'US', 'ES']",
#    'properties.tpo.image': '5ee3bd84c8d35124875069.png',
#    'properties.tpo.address.zipCode': '05482',
#    'properties.tpo.address.country': 'US',
#    'properties.tpo.address.address': '145 Pine Haven Shores Road, Suite 1000D',
#    'properties.tpo.address.city': 'Shelburne',
#    'properties.tpo.name': 'One Tree Planted',
#    'properties.tpo.id': 'tpo_XaEjbTfMh5rfOhVf7646jdpP',
#    'properties.tpo.email': 'projectsplatforms@onetreeplanted.org',
#    'properties.tpo.slug': 'one-tree-planted',
#    'properties.treeCost': 12.0,
#    'properties.unitCost': 12.0,
#    'properties.description': nan,
#    'properties.metadata.degradationCause': nan,
#    'properties.metadata.longTermPlan': nan,
#    'properties.metadata.mainChallenge': nan,
#    'properties.metadata.motivation': nan,
#    'properties.options': '[]',
#    'properties.paymentDefaults': nan,
#    'properties.fixedRates.CHF': nan,
#    'properties.metadata.actions': nan,
#    'properties.metadata.benefits': nan,
#    'properties.metadata.coBenefits': nan,
#    'properties.metadata.ecologicalBenefits': nan,
#    'properties.metadata.socialBenefits': nan}],
#  'proj_2eV54jAVwjsXPqW8irLOedKj': [{'Unnamed: 0': 129,
#    'type': 'Feature',
#    'geometry.type': 'Point',
#    'geometry.coordinates': '[39.97303, -3.35523]',
#    'properties._scope': 'map',
#    'properties.allowDonations': True,
#    'properties.classification': 'large-scale-planting',
#    'properties.countPlanted': 3917.0,
#    'properties.countTarget': 2000000.0,
#    'properties.country': 'KE',
#    'properties.currency': 'EUR',
#    'properties.fixedRates': '[]',
#    'properties.image': '63a39db0d657b274905830.jpg',
#    'properties.isApproved': True,
#    'properties.isFeatured': False,
#    'properties.isPublished': True,
#    'properties.isTopProject': True,
#    'properties.location': nan,
#    'properties.minTreeCount': 0.0,
#    'properties.name': 'SeaTrees Mangrove Forest: Mida Creek and Marereni, Kenya',
#    'properties.paymentDefaults.fixedTreeCountOptions': nan,
#    'properties.paymentDefaults.fixedDefaultTreeCount': nan,
#    'properties.purpose': 'trees',
#    'properties.reviewScore': 0,
#    'properties.reviews': "[{'pdf': '6449b8a63c7e4306935677.pdf', 'id': 'prev_VkUjRYAjy5Op', 'issueMonth': '03-2023'}]",
#    'properties.slug': 'seatreesmidacreek',
#    'properties.taxDeductionCountries': "['DE', 'US', 'ES']",
#    'properties.tpo.image': '63dda14d1f455468724037.png',
#    'properties.tpo.address.zipCode': '90266',
#    'properties.tpo.address.country': 'US',
#    'properties.tpo.address.address': 'PO Box 3058',
#    'properties.tpo.address.city': 'Manhattan Beach',
#    'properties.tpo.name': 'Sustainable Surf',
#    'properties.tpo.id': 'tpo_roDMoDBCMRwcXo2ebBVrJc8N',
#    'properties.tpo.email': 'projects@sustainablesurf.org',
#    'properties.tpo.slug': 'seatrees-1',
#    'properties.treeCost': 0.92,
#    'properties.unitCost': 0.92,
#    'properties.description': nan,
#    'properties.metadata.degradationCause': nan,
#    'properties.metadata.longTermPlan': nan,
#    'properties.metadata.mainChallenge': nan,
#    'properties.metadata.motivation': nan,
#    'properties.options': '[]',
#    'properties.paymentDefaults': nan,
#    'properties.fixedRates.CHF': nan,
#    'properties.metadata.actions': nan,
#    'properties.metadata.benefits': nan,
#    'properties.metadata.coBenefits': nan,
#    'properties.metadata.ecologicalBenefits': nan,
#    'properties.metadata.socialBenefits': nan}],
#  'proj_32MovMetcmr05uGEouJN0HpM': [{'Unnamed: 0': 187,
#    'type': 'Feature',
#    'geometry.type': 'Point',
#    'geometry.coordinates': '[37.2341032247, -1.0174020179159]',
#    'properties._scope': 'map',
#    'properties.allowDonations': False,
#    'properties.classification': 'large-scale-planting',
#    'properties.countPlanted': 6141.0,
#    'properties.countTarget': 100000.0,
#    'properties.country': 'KE',
#    'properties.currency': 'EUR',
#    'properties.fixedRates': '[]',
#    'properties.image': '613a36a64eb4d220296882.jpg',
#    'properties.isApproved': False,
#    'properties.isFeatured': False,
#    'properties.isPublished': True,
#    'properties.isTopProject': False,
#    'properties.location': nan,
#    'properties.minTreeCount': 1.0,
#    'properties.name': 'Kenya - Restoring the Kijabe Forest',
#    'properties.paymentDefaults.fixedTreeCountOptions': '[10, 25, 50, 100]',
#    'properties.paymentDefaults.fixedDefaultTreeCount': 5.0,
#    'properties.purpose': 'trees',
#    'properties.reviewScore': 0,
#    'properties.reviews': '[]',
#    'properties.slug': 'ke-whcr',
#    'properties.taxDeductionCountries': "['DE', 'US', 'ES']",
#    'properties.tpo.image': '5ee3bd84c8d35124875069.png',
#    'properties.tpo.address.zipCode': '05482',
#    'properties.tpo.address.country': 'US',
#    'properties.tpo.address.address': '145 Pine Haven Shores Road, Suite 1000D',
#    'properties.tpo.address.city': 'Shelburne',
#    'properties.tpo.name': 'One Tree Planted',
#    'properties.tpo.id': 'tpo_XaEjbTfMh5rfOhVf7646jdpP',
#    'properties.tpo.email': 'projectsplatforms@onetreeplanted.org',
#    'properties.tpo.slug': 'one-tree-planted',
#    'properties.treeCost': 0.95,
#    'properties.unitCost': 0.95,
#    'properties.description': nan,
#    'properties.metadata.degradationCause': nan,
#    'properties.metadata.longTermPlan': nan,
#    'properties.metadata.mainChallenge': nan,
#    'properties.metadata.motivation': nan,
#    'properties.options': '[]',
#    'properties.paymentDefaults': nan,
#    'properties.fixedRates.CHF': nan,
#    'properties.metadata.actions': nan,
#    'properties.metadata.benefits': nan,
#    'properties.metadata.coBenefits': nan,
#    'properties.metadata.ecologicalBenefits': nan,
#    'properties.metadata.socialBenefits': nan}],
#  'proj_35JZ2XEV2TOaq7mvQCmr1UPC': [{'Unnamed: 0': 120,
#    'type': 'Feature',
#    'geometry.type': 'Point',
#    'geometry.coordinates': '[83.944163469, 28.303150516168]',
#    'properties._scope': 'map',
#    'properties.allowDonations': True,
#    'properties.classification': 'large-scale-planting',
#    'properties.countPlanted': 328538.0,
#    'properties.countTarget': 2500000.0,
#    'properties.country': 'NP',
#    'properties.currency': 'EUR',
#    'properties.fixedRates': '[]',
#    'properties.image': '5f7de441cd659657174339.jpeg',
#    'properties.isApproved': False,
#    'properties.isFeatured': False,
#    'properties.isPublished': True,
#    'properties.isTopProject': False,
#    'properties.location': 'Nepal',
#    'properties.minTreeCount': 2.0,
#    'properties.name': 'Eden Reforestation Projects - Nepal',
#    'properties.paymentDefaults.fixedTreeCountOptions': '[10, 25, 50, 100]',
#    'properties.paymentDefaults.fixedDefaultTreeCount': 5.0,
#    'properties.purpose': 'trees',
#    'properties.reviewScore': 0,
#    'properties.reviews': '[]',
#    'properties.slug': 'eden-reforestation-projects-nepal',
#    'properties.taxDeductionCountries': "['DE', 'US', 'ES']",
#    'properties.tpo.image': '5cae3e3395e52084699403.jpeg',
#    'properties.tpo.address.zipCode': '91741',
#    'properties.tpo.address.country': 'US',
#    'properties.tpo.address.address': '303 W Foothill Blvd. Unit 13',
#    'properties.tpo.address.city': 'Glendora',
#    'properties.tpo.name': 'Eden Reforestation Projects',
#    'properties.tpo.id': 'tpo_4DeNcQv0Dn8bFAm12PlY8zec',
#    'properties.tpo.email': 'info@edenprojects.org',
#    'properties.tpo.slug': 'eden-reforestation-projects',
#    'properties.treeCost': 0.14,
#    'properties.unitCost': 0.14,
#    'properties.description': nan,
#    'properties.metadata.degradationCause': nan,
#    'properties.metadata.longTermPlan': nan,
#    'properties.metadata.mainChallenge': nan,
#    'properties.metadata.motivation': nan,
#    'properties.options': '[]',
#    'properties.paymentDefaults': nan,
#    'properties.fixedRates.CHF': nan,
#    'properties.metadata.actions': nan,
#    'properties.metadata.benefits': nan,
#    'properties.metadata.coBenefits': nan,
#    'properties.metadata.ecologicalBenefits': nan,
#    'properties.metadata.socialBenefits': nan}],
#  'proj_3XSDk54pDgJFiIXa4AX261Rr': [{'Unnamed: 0': 56,
#    'type': 'Feature',
#    'geometry.type': 'Point',
#    'geometry.coordinates': '[-104.12054, 20.460068]',
#    'properties._scope': 'map',
#    'properties.allowDonations': True,
#    'properties.classification': 'large-scale-planting',
#    'properties.countPlanted': 2362.0,
#    'properties.countTarget': 30000.0,
#    'properties.country': 'MX',
#    'properties.currency': 'EUR',
#    'properties.fixedRates': '[]',
#    'properties.image': '6310adeea2826771705492.jpg',
#    'properties.isApproved': False,
#    'properties.isFeatured': False,
#    'properties.isPublished': True,
#    'properties.isTopProject': False,
#    'properties.location': nan,
#    'properties.minTreeCount': 0.0,
#    'properties.name': 'El Magistral Mexico Reforestation 2023',
#    'properties.paymentDefaults.fixedTreeCountOptions': nan,
#    'properties.paymentDefaults.fixedDefaultTreeCount': nan,
#    'properties.purpose': 'trees',
#    'properties.reviewScore': 0,
#    'properties.reviews': '[]',
#    'properties.slug': 'donateatreeelmagistral',
#    'properties.taxDeductionCountries': "['DE', 'US', 'ES']",
#    'properties.tpo.image': '63136a814a0c8890246646.jpg',
#    'properties.tpo.address.zipCode': '44124',
#    'properties.tpo.address.country': 'US',
#    'properties.tpo.address.address': '2869 Lander Rd',
#    'properties.tpo.address.city': 'Cleveland',
#    'properties.tpo.name': 'Donate a Tree to the World',
#    'properties.tpo.id': 'tpo_8b69PmIS2RPJ7mVM4swerK1z',
#    'properties.tpo.email': 'rkphelan@msn.com',
#    'properties.tpo.slug': 'donate-a-tree-to-the-world',
#    'properties.treeCost': 1.0,
#    'properties.unitCost': 1.0,
#    'properties.description': nan,
#    'properties.metadata.degradationCause': nan,
#    'properties.metadata.longTermPlan': nan,
#    'properties.metadata.mainChallenge': nan,
#    'properties.metadata.motivation': nan,
#    'properties.options': '[]',
#    'properties.paymentDefaults': nan,
#    'properties.fixedRates.CHF': nan,
#    'properties.metadata.actions': nan,
#    'properties.metadata.benefits': nan,
#    'properties.metadata.coBenefits': nan,
#    'properties.metadata.ecologicalBenefits': nan,
#    'properties.metadata.socialBenefits': nan}],
#  'proj_3aQZi1SCNWqqmM8duObtYchF': [{'Unnamed: 0': 191,
#    'type': 'Feature',
#    'geometry.type': 'Point',
#    'geometry.coordinates': '[153.48044117351, -28.638515179171]',
#    'properties._scope': 'map',
#    'properties.allowDonations': True,
#    'properties.classification': 'natural-regeneration',
#    'properties.countPlanted': 40857.0,
#    'properties.countTarget': 500000.0,
#    'properties.country': 'AU',
#    'properties.currency': 'EUR',
#    'properties.fixedRates': '[]',
#    'properties.image': '5e4b9cd1d07f9129541964.jpg',
#    'properties.isApproved': False,
#    'properties.isFeatured': False,
#    'properties.isPublished': True,
#    'properties.isTopProject': False,
#    'properties.location': 'Byron Shire region',
#    'properties.minTreeCount': 2.0,
#    'properties.name': 'Byron Bay Subtropical Rainforest Reforestation',
#    'properties.paymentDefaults.fixedTreeCountOptions': '[10, 20, 50, 100]',
#    'properties.paymentDefaults.fixedDefaultTreeCount': 5.0,
#    'properties.purpose': 'trees',
#    'properties.reviewScore': 0,
#    'properties.reviews': '[]',
#    'properties.slug': 'bryon-bay-subtropical-rainforest-reforestation',
#    'properties.taxDeductionCountries': "['DE', 'US', 'ES']",
#    'properties.tpo.image': '5ebcde19ed4c5706861461.png',
#    'properties.tpo.address.zipCode': '2483',
#    'properties.tpo.address.country': 'AU',
#    'properties.tpo.address.address': '3/11 Booyun Street',
#    'properties.tpo.address.city': 'Brunswick Heads',
#    'properties.tpo.name': 'ReForest Now',
#    'properties.tpo.id': 'tpo_0nOR4g219U36r7B4Vb40fKdg',
#    'properties.tpo.email': 'partnerships@reforestnow.org.au',
#    'properties.tpo.slug': 'reforest-now-1',
#    'properties.treeCost': 3.3,
#    'properties.unitCost': 3.3,
#    'properties.description': nan,
#    'properties.metadata.degradationCause': nan,
#    'properties.metadata.longTermPlan': nan,
#    'properties.metadata.mainChallenge': nan,
#    'properties.metadata.motivation': nan,
#    'properties.options': '[]',
#    'properties.paymentDefaults': nan,
#    'properties.fixedRates.CHF': nan,
#    'properties.metadata.actions': nan,
#    'properties.metadata.benefits': nan,
#    'properties.metadata.coBenefits': nan,
#    'properties.metadata.ecologicalBenefits': nan,
#    'properties.metadata.socialBenefits': nan}],
#  'proj_3cXBgeoedy3kuAtzsVC9cqy7': [{'Unnamed: 0': 189,
#    'type': 'Feature',
#    'geometry.type': 'Point',
#    'geometry.coordinates': '[35.683498, -0.593429]',
#    'properties._scope': 'map',
#    'properties.allowDonations': True,
#    'properties.classification': 'large-scale-planting',
#    'properties.countPlanted': 10.0,
#    'properties.countTarget': 200000.0,
#    'properties.country': 'KE',
#    'properties.currency': 'EUR',
#    'properties.fixedRates': '[]',
#    'properties.image': '646f1241ea6dd215670915.jpg',
#    'properties.isApproved': False,
#    'properties.isFeatured': False,
#    'properties.isPublished': True,
#    'properties.isTopProject': False,
#    'properties.location': nan,
#    'properties.minTreeCount': 0.0,
#    'properties.name': 'reforestation organization',
#    'properties.paymentDefaults.fixedTreeCountOptions': nan,
#    'properties.paymentDefaults.fixedDefaultTreeCount': nan,
#    'properties.purpose': 'trees',
#    'properties.reviewScore': 0,
#    'properties.reviews': '[]',
#    'properties.slug': 'nakuru-bomet',
#    'properties.taxDeductionCountries': "['DE', 'US', 'ES']",
#    'properties.tpo.image': nan,
#    'properties.tpo.address.zipCode': '20406',
#    'properties.tpo.address.country': 'KE',
#    'properties.tpo.address.address': '717',
#    'properties.tpo.address.city': 'SOTIK',
#    'properties.tpo.name': 'Youth for Change',
#    'properties.tpo.id': 'tpo_JVEfP5fXjNsnzgNaSr1e6Tqp',
#    'properties.tpo.email': 'betkiprotich@gmail.com',
#    'properties.tpo.slug': 'youth-for-change-1',
#    'properties.treeCost': 2.75,
#    'properties.unitCost': 2.75,
#    'properties.description': nan,
#    'properties.metadata.degradationCause': nan,
#    'properties.metadata.longTermPlan': nan,
#    'properties.metadata.mainChallenge': nan,
#    'properties.metadata.motivation': nan,
#    'properties.options': '[]',
#    'properties.paymentDefaults': nan,
#    'properties.fixedRates.CHF': nan,
#    'properties.metadata.actions': nan,
#    'properties.metadata.benefits': nan,
#    'properties.metadata.coBenefits': nan,
#    'properties.metadata.ecologicalBenefits': nan,
#    'properties.metadata.socialBenefits': nan}],
#  'proj_4Od5ox6KBCQ6wRnnfzXgFmu4': [{'Unnamed: 0': 207,
#    'type': 'Feature',
#    'geometry.type': 'Point',
#    'geometry.coordinates': '[-0.597571, 40.755257]',
#    'properties._scope': 'map',
#    'properties.allowDonations': False,
#    'properties.classification': 'large-scale-planting',
#    'properties.countPlanted': 15319.0,
#    'properties.countTarget': 15319.0,
#    'properties.country': 'ES',
#    'properties.currency': 'EUR',
#    'properties.fixedRates': '[]',
#    'properties.image': '5d2836dd146bf393286119.jpg',
#    'properties.isApproved': False,
#    'properties.isFeatured': False,
#    'properties.isPublished': True,
#    'properties.isTopProject': False,
#    'properties.location': 'Ejulve (Teruel, Aragón) Spain',
#    'properties.minTreeCount': 2.0,
#    'properties.name': 'Permanent Plantation Station – Ejulve',
#    'properties.paymentDefaults.fixedTreeCountOptions': '[10, 25, 50, 100]',
#    'properties.paymentDefaults.fixedDefaultTreeCount': 5.0,
#    'properties.purpose': 'trees',
#    'properties.reviewScore': 0,
#    'properties.reviews': '[]',
#    'properties.slug': 'permanent-plantation-station-ejulve',
#    'properties.taxDeductionCountries': "['DE', 'US', 'ES']",
#    'properties.tpo.image': nan,
#    'properties.tpo.address.zipCode': '08015',
#    'properties.tpo.address.country': 'ES',
#    'properties.tpo.address.address': 'Diputació, 119-121, 3-2',
#    'properties.tpo.address.city': 'Barcelona',
#    'properties.tpo.name': 'Plant-for-the-Planet Spain Foundation',
#    'properties.tpo.id': 'tpo_hIje0zxERUTkGhBwyYBuGG2G',
#    'properties.tpo.email': 'info@planetspain.org',
#    'properties.tpo.slug': 'plant-for-the-planet-spain-foundation',
#    'properties.treeCost': 13.0,
#    'properties.unitCost': 13.0,
#    'properties.description': nan,
#    'properties.metadata.degradationCause': nan,
#    'properties.metadata.longTermPlan': nan,
#    'properties.metadata.mainChallenge': nan,
#    'properties.metadata.motivation': nan,
#    'properties.options': '[]',
#    'properties.paymentDefaults': nan,
#    'properties.fixedRates.CHF': nan,
#    'properties.metadata.actions': nan,
#    'properties.metadata.benefits': nan,
#    'properties.metadata.coBenefits': nan,
#    'properties.metadata.ecologicalBenefits': nan,
#    'properties.metadata.socialBenefits': nan}],
#  'proj_4Xde51IgWMaMaUtEJdTP0Uzc': [{'Unnamed: 0': 180,
#    'type': 'Feature',
#    'geometry.type': 'Point',
#    'geometry.coordinates': '[-76.861956, 0.08526]',
#    'properties._scope': 'map',
#    'properties.allowDonations': True,
#    'properties.classification': 'natural-regeneration',
#    'properties.countPlanted': 5803.0,
#    'properties.countTarget': 8000.0,
#    'properties.country': 'EC',
#    'properties.currency': 'EUR',
#    'properties.fixedRates': '[]',
#    'properties.image': '5dcc114d7fed4755085285.jpg',
#    'properties.isApproved': False,
#    'properties.isFeatured': False,
#    'properties.isPublished': True,
#    'properties.isTopProject': False,
#    'properties.location': 'Sucumbios and Orellana provinces of the Ecuadorian Amazon region',
#    'properties.minTreeCount': 1.0,
#    'properties.name': 'Green Heart Project',
#    'properties.paymentDefaults.fixedTreeCountOptions': '[10, 25, 50, 100]',
#    'properties.paymentDefaults.fixedDefaultTreeCount': 5.0,
#    'properties.purpose': 'trees',
#    'properties.reviewScore': 0,
#    'properties.reviews': '[]',
#    'properties.slug': 'green-heart-project',
#    'properties.taxDeductionCountries': "['DE', 'US', 'ES']",
#    'properties.tpo.image': nan,
#    'properties.tpo.address.zipCode': '10119',
#    'properties.tpo.address.country': 'DE',
#    'properties.tpo.address.address': 'Fehrbelliner Str. 54',
#    'properties.tpo.address.city': 'Berlin',
#    'properties.tpo.name': 'Love for Life e.V.',
#    'properties.tpo.id': 'tpo_aMrocpKUIs3ZJ1dcOjJa3DQC',
#    'properties.tpo.email': 'Thomas@loveforlifeproject.org',
#    'properties.tpo.slug': 'love-for-life-e-v',
#    'properties.treeCost': 4.0,
#    'properties.unitCost': 4.0,
#    'properties.description': nan,
#    'properties.metadata.degradationCause': nan,
#    'properties.metadata.longTermPlan': nan,
#    'properties.metadata.mainChallenge': nan,
#    'properties.metadata.motivation': nan,
#    'properties.options': '[]',
#    'properties.paymentDefaults': nan,
#    'properties.fixedRates.CHF': nan,
#    'properties.metadata.actions': nan,
#    'properties.metadata.benefits': nan,
#    'properties.metadata.coBenefits': nan,
#    'properties.metadata.ecologicalBenefits': nan,
#    'properties.metadata.socialBenefits': nan}],
#  'proj_4c23gFN1xbU8xLD10qugNDkN': [{'Unnamed: 0': 244,
#    'type': 'Feature',
#    'geometry.type': 'Point',
#    'geometry.coordinates': '[80.829582427434, 26.908207516024]',
#    'properties._scope': 'map',
#    'properties.allowDonations': False,
#    'properties.classification': 'urban-planting',
#    'properties.countPlanted': 5000.0,
#    'properties.countTarget': 5000.0,
#    'properties.country': 'IN',
#    'properties.currency': 'EUR',
#    'properties.fixedRates': '[]',
#    'properties.image': '6244fa7a0c81a711871666.PNG',
#    'properties.isApproved': False,
#    'properties.isFeatured': False,
#    'properties.isPublished': True,
#    'properties.isTopProject': False,
#    'properties.location': nan,
#    'properties.minTreeCount': 0.0,
#    'properties.name': 'India 2022 - Salesforce Trees for a Changing Climate',
#    'properties.paymentDefaults.fixedTreeCountOptions': '[0, 0, 0, 0]',
#    'properties.paymentDefaults.fixedDefaultTreeCount': 0.0,
#    'properties.purpose': 'trees',
#    'properties.reviewScore': 0,
#    'properties.reviews': '[]',
#    'properties.slug': 'india-salesforce',
#    'properties.taxDeductionCountries': "['DE', 'US', 'ES']",
#    'properties.tpo.image': '5ee3bd84c8d35124875069.png',
#    'properties.tpo.address.zipCode': '05482',
#    'properties.tpo.address.country': 'US',
#    'properties.tpo.address.address': '145 Pine Haven Shores Road, Suite 1000D',
#    'properties.tpo.address.city': 'Shelburne',
#    'properties.tpo.name': 'One Tree Planted',
#    'properties.tpo.id': 'tpo_XaEjbTfMh5rfOhVf7646jdpP',
#    'properties.tpo.email': 'projectsplatforms@onetreeplanted.org',
#    'properties.tpo.slug': 'one-tree-planted',
#    'properties.treeCost': 11.37,
#    'properties.unitCost': 11.37,
#    'properties.description': nan,
#    'properties.metadata.degradationCause': nan,
#    'properties.metadata.longTermPlan': nan,
#    'properties.metadata.mainChallenge': nan,
#    'properties.metadata.motivation': nan,
#    'properties.options': '[]',
#    'properties.paymentDefaults': nan,
#    'properties.fixedRates.CHF': nan,
#    'properties.metadata.actions': nan,
#    'properties.metadata.benefits': nan,
#    'properties.metadata.coBenefits': nan,
#    'properties.metadata.ecologicalBenefits': nan,
#    'properties.metadata.socialBenefits': nan}],
#  'proj_4jIZiMYhCLt9jDqbk5bMS7js': [{'Unnamed: 0': 97,
#    'type': 'Feature',
#    'geometry.type': 'Point',
#    'geometry.coordinates': '[31.1568428, 1.445901112]',
#    'properties._scope': 'map',
#    'properties.allowDonations': False,
#    'properties.classification': 'natural-regeneration',
#    'properties.countPlanted': 153976.0,
#    'properties.countTarget': 1000000.0,
#    'properties.country': 'UG',
#    'properties.currency': 'EUR',
#    'properties.fixedRates': '[]',
#    'properties.image': '5c0667d4c7691905806080.jpeg',
#    'properties.isApproved': False,
#    'properties.isFeatured': False,
#    'properties.isPublished': True,
#    'properties.isTopProject': False,
#    'properties.location': 'Uganda, Hoima District',
#    'properties.minTreeCount': 1.0,
#    'properties.name': 'Coffee Farming as an Alternative Livelihood',
#    'properties.paymentDefaults.fixedTreeCountOptions': '[1, 1, 1, 1]',
#    'properties.paymentDefaults.fixedDefaultTreeCount': 1.0,
#    'properties.purpose': 'trees',
#    'properties.reviewScore': 0,
#    'properties.reviews': '[]',
#    'properties.slug': 'coffee-farming-as-an-alternative-livelihood',
#    'properties.taxDeductionCountries': "['DE', 'US', 'ES']",
#    'properties.tpo.image': '5d36e79ff2144551873475.jpeg',
#    'properties.tpo.address.zipCode': '245',
#    'properties.tpo.address.country': 'UG',
#    'properties.tpo.address.address': 'PO Box 245',
#    'properties.tpo.address.city': 'Hoima',
#    'properties.tpo.name': 'The Bulindi Chimpanzee & Community Project',
#    'properties.tpo.id': 'tpo_3NCx76sPjt663SvEroJr9Uoa',
#    'properties.tpo.email': 'bccp@bulindichimpanzees.co.uk',
#    'properties.tpo.slug': 'the-bulindi-chimpanzee-community-project',
#    'properties.treeCost': 0.95,
#    'properties.unitCost': 0.95,
#    'properties.description': nan,
#    'properties.metadata.degradationCause': nan,
#    'properties.metadata.longTermPlan': nan,
#    'properties.metadata.mainChallenge': nan,
#    'properties.metadata.motivation': nan,
#    'properties.options': '[]',
#    'properties.paymentDefaults': nan,
#    'properties.fixedRates.CHF': nan,
#    'properties.metadata.actions': nan,
#    'properties.metadata.benefits': nan,
#    'properties.metadata.coBenefits': nan,
#    'properties.metadata.ecologicalBenefits': nan,
#    'properties.metadata.socialBenefits': nan}],
#  'proj_4lodDjNp2pmmw8rXpej7m4yM': [{'Unnamed: 0': 20,
#    'type': 'Feature',
#    'geometry.type': 'Point',
#    'geometry.coordinates': '[82.35993521878, 28.095625814004]',
#    'properties._scope': 'map',
#    'properties.allowDonations': True,
#    'properties.classification': 'agroforestry',
#    'properties.countPlanted': 7.0,
#    'properties.countTarget': 100000.0,
#    'properties.country': 'NP',
#    'properties.currency': 'EUR',
#    'properties.fixedRates': '[]',
#    'properties.image': '62fa3de459514337280164.jpg',
#    'properties.isApproved': False,
#    'properties.isFeatured': False,
#    'properties.isPublished': True,
#    'properties.isTopProject': False,
#    'properties.location': nan,
#    'properties.minTreeCount': 0.0,
#    'properties.name': 'Beljhndi Dudras Restoration Project, Dang Nepal',
#    'properties.paymentDefaults.fixedTreeCountOptions': nan,
#    'properties.paymentDefaults.fixedDefaultTreeCount': nan,
#    'properties.purpose': 'trees',
#    'properties.reviewScore': 0,
#    'properties.reviews': '[]',
#    'properties.slug': 'nepalpsdang',
#    'properties.taxDeductionCountries': "['DE', 'US', 'ES']",
#    'properties.tpo.image': nan,
#    'properties.tpo.address.zipCode': nan,
#    'properties.tpo.address.country': 'NP',
#    'properties.tpo.address.address': nan,
#    'properties.tpo.address.city': nan,
#    'properties.tpo.name': 'Partnership for Sustainable Development Nepal (PSDN)',
#    'properties.tpo.id': 'prf_S5hy5o80hF0D7E2mQBAXNR6e',
#    'properties.tpo.email': 'psdnepal79@gmail.com',
#    'properties.tpo.slug': 'psdn-nepal',
#    'properties.treeCost': 12.58,
#    'properties.unitCost': 12.58,
#    'properties.description': nan,
#    'properties.metadata.degradationCause': nan,
#    'properties.metadata.longTermPlan': nan,
#    'properties.metadata.mainChallenge': nan,
#    'properties.metadata.motivation': nan,
#    'properties.options': '[]',
#    'properties.paymentDefaults': nan,
#    'properties.fixedRates.CHF': nan,
#    'properties.metadata.actions': nan,
#    'properties.metadata.benefits': nan,
#    'properties.metadata.coBenefits': nan,
#    'properties.metadata.ecologicalBenefits': nan,
# ...
#    'properties.metadata.mainChallenge': nan,
#    'properties.metadata.motivation': nan,
#    'properties.options': '[]',
#    'properties.paymentDefaults': nan,
#    'properties.fixedRates.CHF': nan,
#    'properties.metadata.actions': nan,
#    'properties.metadata.benefits': nan,
#    'properties.metadata.coBenefits': nan,
#    'properties.metadata.ecologicalBenefits': nan,
#    'properties.metadata.socialBenefits': nan}],
#  'proj_yu519XDEFEIkROyEtA3x2tfH': [{'Unnamed: 0': 32,
#    'type': 'Feature',
#    'geometry.type': 'Point',
#    'geometry.coordinates': '[31.218307591495, 1.4812114028253]',
#    'properties._scope': 'map',
#    'properties.allowDonations': False,
#    'properties.classification': 'other-planting',
#    'properties.countPlanted': 3941.0,
#    'properties.countTarget': 5000000.0,
#    'properties.country': 'UG',
#    'properties.currency': 'EUR',
#    'properties.fixedRates': '[]',
#    'properties.image': '6147ae2dc7cf5885827566.jpg',
#    'properties.isApproved': False,
#    'properties.isFeatured': False,
#    'properties.isPublished': True,
#    'properties.isTopProject': False,
#    'properties.location': nan,
#    'properties.minTreeCount': 1.0,
#    'properties.name': 'Budongo-Bugoma Wildlife Habitat & Corridor Restoration Project – Phase 2',
#    'properties.paymentDefaults.fixedTreeCountOptions': '[10, 25, 50, 100]',
#    'properties.paymentDefaults.fixedDefaultTreeCount': 5.0,
#    'properties.purpose': 'trees',
#    'properties.reviewScore': 0,
#    'properties.reviews': '[]',
#    'properties.slug': 'jgi-budongo-bugoma-restore',
#    'properties.taxDeductionCountries': "['DE', 'US', 'ES']",
#    'properties.tpo.image': nan,
#    'properties.tpo.address.zipCode': '20036',
#    'properties.tpo.address.country': 'US',
#    'properties.tpo.address.address': '1120 20th St. NW, #520s',
#    'properties.tpo.address.city': 'Washington',
#    'properties.tpo.name': 'Jane Goodall Institute - USA',
#    'properties.tpo.id': 'tpo_yXD78K1WOIwXOLrohlKJNQI1',
#    'properties.tpo.email': 'treesfor@janegoodall.org',
#    'properties.tpo.slug': 'the-jane-goodall-institute',
#    'properties.treeCost': 2.37,
#    'properties.unitCost': 2.37,
#    'properties.description': nan,
#    'properties.metadata.degradationCause': nan,
#    'properties.metadata.longTermPlan': nan,
#    'properties.metadata.mainChallenge': nan,
#    'properties.metadata.motivation': nan,
#    'properties.options': '[]',
#    'properties.paymentDefaults': nan,
#    'properties.fixedRates.CHF': nan,
#    'properties.metadata.actions': nan,
#    'properties.metadata.benefits': nan,
#    'properties.metadata.coBenefits': nan,
#    'properties.metadata.ecologicalBenefits': nan,
#    'properties.metadata.socialBenefits': nan}],
#  'proj_yyFAQ7H75v6dg5ql5H7RnGbK': [{'Unnamed: 0': 238,
#    'type': 'Feature',
#    'geometry.type': 'Point',
#    'geometry.coordinates': '[31.765672, -12.088495]',
#    'properties._scope': 'map',
#    'properties.allowDonations': False,
#    'properties.classification': 'agroforestry',
#    'properties.countPlanted': 30000000.0,
#    'properties.countTarget': 30000000.0,
#    'properties.country': 'ZM',
#    'properties.currency': 'EUR',
#    'properties.fixedRates': '[]',
#    'properties.image': '60d199f4aab09811186030.jpg',
#    'properties.isApproved': False,
#    'properties.isFeatured': False,
#    'properties.isPublished': True,
#    'properties.isTopProject': False,
#    'properties.location': 'Luangwa Valley, Central and Muchinga Provinces',
#    'properties.minTreeCount': 2.0,
#    'properties.name': 'Restoring Trees and Livelihoods in Zambia',
#    'properties.paymentDefaults.fixedTreeCountOptions': '[10, 25, 50, 100]',
#    'properties.paymentDefaults.fixedDefaultTreeCount': 5.0,
#    'properties.purpose': 'trees',
#    'properties.reviewScore': 0,
#    'properties.reviews': '[]',
#    'properties.slug': 'restoring-trees-and-livelihoods-in-zambia',
#    'properties.taxDeductionCountries': "['DE', 'US', 'ES']",
#    'properties.tpo.image': nan,
#    'properties.tpo.address.zipCode': nan,
#    'properties.tpo.address.country': 'AU',
#    'properties.tpo.address.address': nan,
#    'properties.tpo.address.city': nan,
#    'properties.tpo.name': 'Global EverGreening Alliance',
#    'properties.tpo.id': 'prf_gsrVJUWCr7BmT11Zyy9pfkHg',
#    'properties.tpo.email': 'emma.drew@evergreening.org',
#    'properties.tpo.slug': 'global-evergreening-alliance',
#    'properties.treeCost': 0.0,
#    'properties.unitCost': 0.0,
#    'properties.description': nan,
#    'properties.metadata.degradationCause': nan,
#    'properties.metadata.longTermPlan': nan,
#    'properties.metadata.mainChallenge': nan,
#    'properties.metadata.motivation': nan,
#    'properties.options': '[]',
#    'properties.paymentDefaults': nan,
#    'properties.fixedRates.CHF': nan,
#    'properties.metadata.actions': nan,
#    'properties.metadata.benefits': nan,
#    'properties.metadata.coBenefits': nan,
#    'properties.metadata.ecologicalBenefits': nan,
#    'properties.metadata.socialBenefits': nan}],
#  'proj_z4VFz8QZq2suDRaydA14xYsO': [{'Unnamed: 0': 9,
#    'type': 'Feature',
#    'geometry.type': 'Point',
#    'geometry.coordinates': '[32.36515, 3.11538]',
#    'properties._scope': 'map',
#    'properties.allowDonations': True,
#    'properties.classification': 'managed-regeneration',
#    'properties.countPlanted': 834.0,
#    'properties.countTarget': 50000.0,
#    'properties.country': 'UG',
#    'properties.currency': 'EUR',
#    'properties.fixedRates': '[]',
#    'properties.image': '6082602501965005649250.jpeg',
#    'properties.isApproved': False,
#    'properties.isFeatured': False,
#    'properties.isPublished': True,
#    'properties.isTopProject': False,
#    'properties.location': nan,
#    'properties.minTreeCount': 0.0,
#    'properties.name': 'Trees for Girls Education',
#    'properties.paymentDefaults.fixedTreeCountOptions': nan,
#    'properties.paymentDefaults.fixedDefaultTreeCount': nan,
#    'properties.purpose': 'trees',
#    'properties.reviewScore': 0,
#    'properties.reviews': '[]',
#    'properties.slug': 'treesforgirlseducation',
#    'properties.taxDeductionCountries': "['DE', 'US', 'ES']",
#    'properties.tpo.image': nan,
#    'properties.tpo.address.zipCode': '93108',
#    'properties.tpo.address.country': 'US',
#    'properties.tpo.address.address': '801 Cold Spring Road',
#    'properties.tpo.address.city': 'Santa Barbara',
#    'properties.tpo.name': 'African Women Rising',
#    'properties.tpo.id': 'tpo_n1WRYG6D3p1tXKV3hrYjjjuF',
#    'properties.tpo.email': 'linda@africanwomenrising.org',
#    'properties.tpo.slug': 'african-women-rising',
#    'properties.treeCost': 3.0,
#    'properties.unitCost': 3.0,
#    'properties.description': nan,
#    'properties.metadata.degradationCause': nan,
#    'properties.metadata.longTermPlan': nan,
#    'properties.metadata.mainChallenge': nan,
#    'properties.metadata.motivation': nan,
#    'properties.options': '[]',
#    'properties.paymentDefaults': nan,
#    'properties.fixedRates.CHF': nan,
#    'properties.metadata.actions': nan,
#    'properties.metadata.benefits': nan,
#    'properties.metadata.coBenefits': nan,
#    'properties.metadata.ecologicalBenefits': nan,
#    'properties.metadata.socialBenefits': nan}],
#  'proj_zD0ka2pSTr202yEj6SQFAzxF': [{'Unnamed: 0': 154,
#    'type': 'Feature',
#    'geometry.type': 'Point',
#    'geometry.coordinates': '[39.112207031448, -6.7823307478945996]',
#    'properties._scope': 'map',
#    'properties.allowDonations': True,
#    'properties.classification': 'natural-regeneration',
#    'properties.countPlanted': 7273.0,
#    'properties.countTarget': 250000.0,
#    'properties.country': 'TZ',
#    'properties.currency': 'EUR',
#    'properties.fixedRates': '[]',
#    'properties.image': '637b3d8b271f1425699220.jpg',
#    'properties.isApproved': False,
#    'properties.isFeatured': False,
#    'properties.isPublished': True,
#    'properties.isTopProject': False,
#    'properties.location': nan,
#    'properties.minTreeCount': 0.0,
#    'properties.name': 'RESTORATION OF THE BURNT TARAWE FOREST RESERVE-HANDENI,TANZANIA',
#    'properties.paymentDefaults.fixedTreeCountOptions': nan,
#    'properties.paymentDefaults.fixedDefaultTreeCount': nan,
#    'properties.purpose': 'trees',
#    'properties.reviewScore': 0,
#    'properties.reviews': '[]',
#    'properties.slug': 'http-www-inukayouth-org-1',
#    'properties.taxDeductionCountries': "['DE', 'US', 'ES']",
#    'properties.tpo.image': '62f4f54f29788128940734.png',
#    'properties.tpo.address.zipCode': '00000',
#    'properties.tpo.address.country': 'TZ',
#    'properties.tpo.address.address': 'P.O.Box 356 Handeni Tanga-Tanzania',
#    'properties.tpo.address.city': 'Tanga-Tanzania',
#    'properties.tpo.name': 'Inuka Youth Development Organization',
#    'properties.tpo.id': 'prf_DkRx7Gadboaq9yDvOibWjOzb',
#    'properties.tpo.email': 'inukayouth2021@gmail.com',
#    'properties.tpo.slug': 'inuka-youth-development-organization',
#    'properties.treeCost': 0.41,
#    'properties.unitCost': 0.41,
#    'properties.description': nan,
#    'properties.metadata.degradationCause': nan,
#    'properties.metadata.longTermPlan': nan,
#    'properties.metadata.mainChallenge': nan,
#    'properties.metadata.motivation': nan,
#    'properties.options': '[]',
#    'properties.paymentDefaults': nan,
#    'properties.fixedRates.CHF': nan,
#    'properties.metadata.actions': nan,
#    'properties.metadata.benefits': nan,
#    'properties.metadata.coBenefits': nan,
#    'properties.metadata.ecologicalBenefits': nan,
#    'properties.metadata.socialBenefits': nan}],
#  'proj_zlEj4pfcjaux7XVOH2gUvUXU': [{'Unnamed: 0': 134,
#    'type': 'Feature',
#    'geometry.type': 'Point',
#    'geometry.coordinates': '[97.30532111487759, 3.599069393337873]',
#    'properties._scope': 'map',
#    'properties.allowDonations': True,
#    'properties.classification': nan,
#    'properties.countPlanted': nan,
#    'properties.countTarget': 70516.0,
#    'properties.country': 'ID',
#    'properties.currency': 'EUR',
#    'properties.fixedRates': '[]',
#    'properties.image': '61e1cba5e20b7973102191.JPG',
#    'properties.isApproved': nan,
#    'properties.isFeatured': nan,
#    'properties.isPublished': True,
#    'properties.isTopProject': nan,
#    'properties.location': nan,
#    'properties.minTreeCount': nan,
#    'properties.name': 'Strengthening Women’s Initiatives to Protect the Leuser Ecosystem in Aceh Province, Indonesia',
#    'properties.paymentDefaults.fixedTreeCountOptions': nan,
#    'properties.paymentDefaults.fixedDefaultTreeCount': nan,
#    'properties.purpose': 'conservation',
#    'properties.reviewScore': 0,
#    'properties.reviews': '[]',
#    'properties.slug': 'conservation-wea-leuser',
#    'properties.taxDeductionCountries': "['DE', 'US', 'ES']",
#    'properties.tpo.image': '611c3a82614fd369033389.jpg',
#    'properties.tpo.address.zipCode': '94704',
#    'properties.tpo.address.country': 'US',
#    'properties.tpo.address.address': '2150 Allston Way Suite 460',
#    'properties.tpo.address.city': 'Berkeley',
#    'properties.tpo.name': "Women's Earth Alliance",
#    'properties.tpo.id': 'prf_DPuHSu4G1RXXIZ1nAvqG68CE',
#    'properties.tpo.email': 'info@womensearthalliance.org',
#    'properties.tpo.slug': 'womens-earth-alliance',
#    'properties.treeCost': nan,
#    'properties.unitCost': 0.0,
#    'properties.description': nan,
#    'properties.metadata.degradationCause': nan,
#    'properties.metadata.longTermPlan': nan,
#    'properties.metadata.mainChallenge': nan,
#    'properties.metadata.motivation': nan,
#    'properties.options': '[]',
#    'properties.paymentDefaults': nan,
#    'properties.fixedRates.CHF': nan,
#    'properties.metadata.actions': nan,
#    'properties.metadata.benefits': nan,
#    'properties.metadata.coBenefits': nan,
#    'properties.metadata.ecologicalBenefits': nan,
#    'properties.metadata.socialBenefits': nan}],
#  'proj_zoj2MAHlXzibgydQbif5CZBo': [{'Unnamed: 0': 235,
#    'type': 'Feature',
#    'geometry.type': 'Point',
#    'geometry.coordinates': '[-102.20059, 19.888410996463]',
#    'properties._scope': 'map',
#    'properties.allowDonations': True,
#    'properties.classification': 'large-scale-planting',
#    'properties.countPlanted': 949.0,
#    'properties.countTarget': 120000000.0,
#    'properties.country': 'MX',
#    'properties.currency': 'EUR',
#    'properties.fixedRates': '[]',
#    'properties.image': '5fa25981108c2817010985.jpg',
#    'properties.isApproved': False,
#    'properties.isFeatured': False,
#    'properties.isPublished': True,
#    'properties.isTopProject': False,
#    'properties.location': 'Mexico',
#    'properties.minTreeCount': 2.0,
#    'properties.name': 'Ejido Verde',
#    'properties.paymentDefaults.fixedTreeCountOptions': '[5, 10, 25, 50]',
#    'properties.paymentDefaults.fixedDefaultTreeCount': 2.0,
#    'properties.purpose': 'trees',
#    'properties.reviewScore': 0,
#    'properties.reviews': '[]',
#    'properties.slug': 'ejido-verde',
#    'properties.taxDeductionCountries': "['DE', 'US', 'ES']",
#    'properties.tpo.image': '5f89cd41ea7bc205508661.jpeg',
#    'properties.tpo.address.zipCode': '06100',
#    'properties.tpo.address.country': 'MX',
#    'properties.tpo.address.address': 'Culiacán 115',
#    'properties.tpo.address.city': 'Ciudad de México',
#    'properties.tpo.name': 'Reforestamos México, A.C',
#    'properties.tpo.id': 'tpo_nOOBKc5Xp3KBx6KUBDmUzkFp',
#    'properties.tpo.email': 'juanmanuel@reforestamos.org',
#    'properties.tpo.slug': 'reforestamos-mexico-a-c',
#    'properties.treeCost': 5.0,
#    'properties.unitCost': 5.0,
#    'properties.description': nan,
#    'properties.metadata.degradationCause': nan,
#    'properties.metadata.longTermPlan': nan,
#    'properties.metadata.mainChallenge': nan,
#    'properties.metadata.motivation': nan,
#    'properties.options': '[]',
#    'properties.paymentDefaults': nan,
#    'properties.fixedRates.CHF': nan,
#    'properties.metadata.actions': nan,
#    'properties.metadata.benefits': nan,
#    'properties.metadata.coBenefits': nan,
#    'properties.metadata.ecologicalBenefits': nan,
#    'properties.metadata.socialBenefits': nan}],
#  'proj_zz04IRduufUFOMe1AMJniPf9': [{'Unnamed: 0': 26,
#    'type': 'Feature',
#    'geometry.type': 'Point',
#    'geometry.coordinates': '[125.22972222222, 6.4730556]',
#    'properties._scope': 'map',
#    'properties.allowDonations': True,
#    'properties.classification': 'natural-regeneration',
#    'properties.countPlanted': 14716.0,
#    'properties.countTarget': 40000.0,
#    'properties.country': 'PH',
#    'properties.currency': 'EUR',
#    'properties.fixedRates': '[]',
#    'properties.image': '5d6689463f224908891912.jpg',
#    'properties.isApproved': False,
#    'properties.isFeatured': False,
#    'properties.isPublished': True,
#    'properties.isTopProject': False,
#    'properties.location': 'South Cotabato, Mindanao',
#    'properties.minTreeCount': 1.0,
#    'properties.name': 'Plant a giant tree and defend rainforest in the Philippines',
#    'properties.paymentDefaults.fixedTreeCountOptions': '[1, 1, 1, 1]',
#    'properties.paymentDefaults.fixedDefaultTreeCount': 1.0,
#    'properties.purpose': 'trees',
#    'properties.reviewScore': 0,
#    'properties.reviews': '[]',
#    'properties.slug': 'plant-a-giant-tree-and-defend-rainforest-in-the-philippines',
#    'properties.taxDeductionCountries': "['DE', 'US', 'ES']",
#    'properties.tpo.image': '5d6688e4eeac8593813280.gif',
#    'properties.tpo.address.zipCode': '94118',
#    'properties.tpo.address.country': 'US',
#    'properties.tpo.address.address': '5108 Hayes St.',
#    'properties.tpo.address.city': 'San Francisco',
#    'properties.tpo.name': 'Endangered Species International',
#    'properties.tpo.id': 'tpo_gn2NWesZeY8sgFMWI3lK4xRg',
#    'properties.tpo.email': 'info@endangeredspeciesinternational.org',
#    'properties.tpo.slug': 'endangered-species-international',
#    'properties.treeCost': 0.95,
#    'properties.unitCost': 0.95,
#    'properties.description': nan,
#    'properties.metadata.degradationCause': nan,
#    'properties.metadata.longTermPlan': nan,
#    'properties.metadata.mainChallenge': nan,
#    'properties.metadata.motivation': nan,
#    'properties.options': '[]',
#    'properties.paymentDefaults': nan,
#    'properties.fixedRates.CHF': nan,
#    'properties.metadata.actions': nan,
#    'properties.metadata.benefits': nan,
#    'properties.metadata.coBenefits': nan,
#    'properties.metadata.ecologicalBenefits': nan,
#    'properties.metadata.socialBenefits': nan}]}

# %%
all_projects = df['properties.id'].unique()

project_info = {}
for slug in all_projects:
    url = f"https://app.plant-for-the-planet.org/app/projects/{slug}?_scope=extended&currency=EUR&locale=en"
    response = requests.get(url)
    if response.status_code == 200:
        project_info[slug] = response.json()
    else:
        project_info[slug] = f"Failed to retrieve information for {slug}"

with open('../input/Plant_for_planet_shapefiles/project_info.json', 'w') as json_file:
    json.dump(project_info, json_file)

print("Project information saved to '../input/Plant_for_planet_shapefiles/project_info.json'")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Project information saved to '../input/Plant_for_planet_shapefiles/project_info.json'

# %% [markdown]
# # Preprocessing

# %%
# Reading the all the data in the json file and we transpose to have the right format table
json_file_path ='../input/Plant_for_planet_shapefiles/project_info.json'
raw_df = pd.read_json(json_file_path).T
raw_df.head(5)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#                                                           id    _scope  \
# proj_ezpAp1POh20dBnYpx0BjhU35  proj_ezpAp1POh20dBnYpx0BjhU35  extended
# proj_ZCspL8JYmUu0OXcx6O73I1j0  proj_ZCspL8JYmUu0OXcx6O73I1j0  extended
# proj_nXBzA2sbX2tm1D75p7bfJ81Z  proj_nXBzA2sbX2tm1D75p7bfJ81Z  extended
# proj_wMNVTLkRIZ4TcV8oi26wlRwN  proj_wMNVTLkRIZ4TcV8oi26wlRwN  extended
# proj_vH52lGTvcjbCGKG4dINKsXJU  proj_vH52lGTvcjbCGKG4dINKsXJU  extended
#
#                               allowDonations certificates  \
# proj_ezpAp1POh20dBnYpx0BjhU35           True           []
# proj_ZCspL8JYmUu0OXcx6O73I1j0           True           []
# proj_nXBzA2sbX2tm1D75p7bfJ81Z           True           []
# proj_wMNVTLkRIZ4TcV8oi26wlRwN           True           []
# proj_vH52lGTvcjbCGKG4dINKsXJU          False           []
#
#                                      classification  \
# proj_ezpAp1POh20dBnYpx0BjhU35          agroforestry
# proj_ZCspL8JYmUu0OXcx6O73I1j0        other-planting
# proj_nXBzA2sbX2tm1D75p7bfJ81Z  large-scale-planting
# proj_wMNVTLkRIZ4TcV8oi26wlRwN          agroforestry
# proj_vH52lGTvcjbCGKG4dINKsXJU          agroforestry
#
#                                                               coordinates  \
# proj_ezpAp1POh20dBnYpx0BjhU35           {'lon': -49.5903, 'lat': -9.2045}
# proj_ZCspL8JYmUu0OXcx6O73I1j0      {'lon': -43.468833, 'lat': -22.495032}
# proj_nXBzA2sbX2tm1D75p7bfJ81Z  {'lon': -1.979117, 'lat': 8.2204420012607}
# proj_wMNVTLkRIZ4TcV8oi26wlRwN       {'lon': 104.791856, 'lat': 20.700794}
# proj_vH52lGTvcjbCGKG4dINKsXJU        {'lon': -67.945206, 'lat': 6.169667}
#
#                               countDonated countPlanted countRegistered  \
# proj_ezpAp1POh20dBnYpx0BjhU35          313          313               0
# proj_ZCspL8JYmUu0OXcx6O73I1j0         3572         3573               0
# proj_nXBzA2sbX2tm1D75p7bfJ81Z        48852        48852               0
# proj_wMNVTLkRIZ4TcV8oi26wlRwN          155          155               0
# proj_vH52lGTvcjbCGKG4dINKsXJU           24        30024           30000
#
#                               countTarget  ... treeCost unitCost unitType  \
# proj_ezpAp1POh20dBnYpx0BjhU35        2000  ...      3.9      3.9     tree
# proj_ZCspL8JYmUu0OXcx6O73I1j0     1000000  ...      4.9      4.9     tree
# proj_nXBzA2sbX2tm1D75p7bfJ81Z    10000000  ...      2.0      2.0     tree
# proj_wMNVTLkRIZ4TcV8oi26wlRwN      100000  ...      8.5      8.5     tree
# proj_vH52lGTvcjbCGKG4dINKsXJU      212500  ...    13.53    13.53     tree
#
#                                 unitsContributed       unitsTargeted  \
# proj_ezpAp1POh20dBnYpx0BjhU35    {'tree': 313.0}      {'tree': 2000}
# proj_ZCspL8JYmUu0OXcx6O73I1j0   {'tree': 3654.2}   {'tree': 1000000}
# proj_nXBzA2sbX2tm1D75p7bfJ81Z  {'tree': 49371.6}  {'tree': 10000000}
# proj_wMNVTLkRIZ4TcV8oi26wlRwN    {'tree': 155.0}    {'tree': 100000}
# proj_vH52lGTvcjbCGKG4dINKsXJU       {'tree': 24}    {'tree': 212500}
#
#                                                                        videoUrl  \
# proj_ezpAp1POh20dBnYpx0BjhU35       https://www.youtube.com/watch?v=9GrWYgJnFqM
# proj_ZCspL8JYmUu0OXcx6O73I1j0                                              None
# proj_nXBzA2sbX2tm1D75p7bfJ81Z  https://youtu.be/f7koI_yKNtI?si=Wtu9dCV8mcCMZxq2
# proj_wMNVTLkRIZ4TcV8oi26wlRwN                                              None
# proj_vH52lGTvcjbCGKG4dINKsXJU                                              None
#
#                               visitorAssistance  \
# proj_ezpAp1POh20dBnYpx0BjhU35              True
# proj_ZCspL8JYmUu0OXcx6O73I1j0              True
# proj_nXBzA2sbX2tm1D75p7bfJ81Z              True
# proj_wMNVTLkRIZ4TcV8oi26wlRwN              True
# proj_vH52lGTvcjbCGKG4dINKsXJU             False
#
#                                                                          website  \
# proj_ezpAp1POh20dBnYpx0BjhU35  https://ecosystemrestorationcamps.org/camp-far...
# proj_ZCspL8JYmUu0OXcx6O73I1j0                             http://www.itpa.org.br
# proj_nXBzA2sbX2tm1D75p7bfJ81Z  https://www.plant-for-the-planet.org/plant-for...
# proj_wMNVTLkRIZ4TcV8oi26wlRwN                                        trofaco.org
# proj_vH52lGTvcjbCGKG4dINKsXJU                        https://www.kardianuts.com/
#
#                               yearAbandoned yearAcquired
# proj_ezpAp1POh20dBnYpx0BjhU35          2012         2012
# proj_ZCspL8JYmUu0OXcx6O73I1j0          2012         None
# proj_nXBzA2sbX2tm1D75p7bfJ81Z          1996         2020
# proj_wMNVTLkRIZ4TcV8oi26wlRwN          2018         2021
# proj_vH52lGTvcjbCGKG4dINKsXJU             0         None
#
# [5 rows x 61 columns]

# %%
raw_df.rename(columns= {"id":"project_id_reported", 
                        "description":"project_description_reported",
                        "countPlanted":"trees_planted_reported", 
                        "firstTreePlanted": "planting_date_reported",
                        "survivalRate": "survival_rate_reported"}, inplace = True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
raw_df.info()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <class 'pandas.core.frame.DataFrame'>
# Index: 263 entries, proj_ezpAp1POh20dBnYpx0BjhU35 to proj_YeRIxbP2YYWz27zTOzZi5wFH
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   project_id_reported           263 non-null    object
#  1   _scope                        263 non-null    object
#  2   allowDonations                263 non-null    object
#  3   certificates                  263 non-null    object
#  4   classification                257 non-null    object
#  5   coordinates                   263 non-null    object
#  6   countDonated                  257 non-null    object
#  7   trees_planted_reported        257 non-null    object
#  8   countRegistered               257 non-null    object
#  9   countTarget                   263 non-null    object
#  10  country                       263 non-null    object
#  11  currency                      263 non-null    object
#  12  degradationCause              171 non-null    object
#  13  degradationYear               249 non-null    object
#  14  project_description_reported  263 non-null    object
#  15  employeesCount                250 non-null    object
#  16  enableInterventions           257 non-null    object
#  17  expenses                      263 non-null    object
#  18  planting_date_reported        136 non-null    object
#  19  fixedRates                    1 non-null      object
#  20  geoLocation                   263 non-null    object
#  21  image                         263 non-null    object
#  22  images                        263 non-null    object
#  23  intensity                     33 non-null     object
#  24  isApproved                    257 non-null    object
#  25  isCertified                   257 non-null    object
#  26  isPublished                   263 non-null    object
#  27  isTopProject                  257 non-null    object
#  28  lastUpdated                   263 non-null    object
#  29  location                      163 non-null    object
#  30  longTermPlan                  164 non-null    object
#  31  mainChallenge                 154 non-null    object
#  32  metadata                      263 non-null    object
#  33  minQuantity                   200 non-null    object
#  34  minTreeCount                  257 non-null    object
#  35  motivation                    176 non-null    object
#  36  name                          263 non-null    object
#  37  options                       263 non-null    object
#  38  paymentDefaults               219 non-null    object
#  39  plantingDensity               99 non-null     object
#  40  plantingSeasons               252 non-null    object
#  41  purpose                       263 non-null    object
#  42  reviews                       263 non-null    object
#  43  siteOwnerName                 136 non-null    object
#  44  siteOwnerType                 232 non-null    object
#  45  sites                         263 non-null    object
#  46  slug                          263 non-null    object
#  47  survival_rate_reported        165 non-null    object
#  48  survivalRateStatus            165 non-null    object
#  49  taxDeductionCountries         263 non-null    object
#  50  tpo                           263 non-null    object
#  51  treeCost                      261 non-null    object
#  52  unitCost                      261 non-null    object
#  53  unitType                      263 non-null    object
#  54  unitsContributed              240 non-null    object
#  55  unitsTargeted                 258 non-null    object
#  56  videoUrl                      127 non-null    object
#  57  visitorAssistance             257 non-null    object
#  58  website                       262 non-null    object
#  59  yearAbandoned                 248 non-null    object
#  60  yearAcquired                  122 non-null    object
# dtypes: object(61)
# memory usage: 135.5+ KB

# %% [markdown]
# ### Convert nested polygons to one polygon per row

# %%
expanded_rows = []
for _, row in raw_df.iterrows():
    for site in row['sites']:
        
        site_data = {
            'project_id_reported': row['project_id_reported'],
            'geometry': site['geometry'],
            'site_id_reported': site['properties']['id'],
            'site_description_reported': site['properties']['description'],
            'site_status_reported': site['properties']['status']
        }
        expanded_rows.append(site_data)

df = pd.DataFrame(expanded_rows)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
df['geometry'] = df['geometry'].apply(lambda x: shape(x) if x is not None else Polygon())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
df[df.geometry.isna()]
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Empty DataFrame
# Columns: [project_id_reported, geometry, site_id_reported, site_description_reported, site_status_reported]
# Index: []

# %%
raw_gdf = gpd.GeoDataFrame(df, geometry='geometry', crs = 'EPSG:4326')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
raw_gdf.head(5)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#              project_id_reported  \
# 0  proj_ezpAp1POh20dBnYpx0BjhU35
# 1  proj_ZCspL8JYmUu0OXcx6O73I1j0
# 2  proj_ZCspL8JYmUu0OXcx6O73I1j0
# 3  proj_ZCspL8JYmUu0OXcx6O73I1j0
# 4  proj_nXBzA2sbX2tm1D75p7bfJ81Z
#
#                                             geometry      site_id_reported  \
# 0  POLYGON ((-49.95883 -9.35107, -49.95976 -9.351...  site_W97pqKxXURFOA1E
# 1  POLYGON Z ((-43.47250 -22.48945 0.00000, -43.4...  site_NekKEGqkIO4rZ5C
# 2  POLYGON Z ((-43.46200 -22.47790 0.00000, -43.4...  site_Wl3hF91IBkei1Xy
# 3  POLYGON Z ((-43.46833 -22.49190 0.00000, -43.4...  site_qHUXswEmePqou5T
# 4  POLYGON ((-1.99088 8.22041, -1.99354 8.23531, ...  site_2ITLGnOa3jbDUFa
#
#                            site_description_reported site_status_reported
# 0             Farm for the Future demonstration plot             planting
# 1  The area to be reforested is around the Tinguá...             planting
# 2  The area to be reforested is around the Tinguá...             planting
# 3  The area to be reforested is around the Tinguá...             planting
# 4  Plant-for-Ghana is a pioneer reforestation pro...             planting

# %% [markdown]
# Check if raw geometry contains invalid geometries

# %% [markdown]
# Explode multipolygons to multiple simple polygons

# %%
gdf = raw_gdf.copy()

while 'MultiPolygon' in gdf.geometry.geom_type.unique().tolist():
    gdf = gdf.explode(index_parts=False)
    gdf['geometry'] = gdf['geometry'].make_valid()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Only keep polygons and points

# %%
gdf = gdf.loc[gdf.geometry.geom_type.isin(['Polygon', 'Point'])].copy()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Simplify 3D to 2D

# %%
gdf['geometry'] = gdf['geometry'].apply(convert_3d_to_2d)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/geopandas/geoseries.py:645: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   result = super().apply(func, convert_dtype=convert_dtype, args=args, **kwargs)

# %%
# Resetting the index without keeping the old index as a column
gdf.reset_index(drop=True, inplace=True)
gdf.info()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 3382 entries, 0 to 3381
# Data columns (total 5 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   project_id_reported        3382 non-null   object
#  1   site_id_reported           3382 non-null   object
#  2   site_description_reported  1972 non-null   object
#  3   site_status_reported       3380 non-null   object
#  4   geometry                   3382 non-null   geometry
# dtypes: geometry(1), object(4)
# memory usage: 132.2+ KB

# %% [markdown]
# Add area sizes

# %%
gdf['site_sqkm'] = gdf['geometry'].to_crs(3857).area / 1e6
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
gdf['site_sqkm'].describe()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# count     3382.000000
# mean        62.283820
# std        897.704562
# min          0.000000
# 25%          0.005371
# 50%          0.023971
# 75%          0.110689
# max      37409.490953
# Name: site_sqkm, dtype: float64

# %% [markdown]
# ### Add project-level information

# %%
gdf = gdf.merge(raw_df[['project_id_reported', 'trees_planted_reported', 'country',"project_description_reported","planting_date_reported","survival_rate_reported"]],
                on = 'project_id_reported', how = 'left')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Fix datetime

# %%
gdf['planting_date_reported'] = pd.to_datetime(gdf['planting_date_reported']).dt.year
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
gdf['planting_date_reported']
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 0          NaN
# 1       2012.0
# 2       2012.0
# 3       2012.0
# 4       2021.0
#          ...
# 3377       NaN
# 3378       NaN
# 3379       NaN
# 3380       NaN
# 3381    2022.0
# Name: planting_date_reported, Length: 3382, dtype: float64

# %%
invalid_geom = False

if len(gdf[gdf.geometry.is_valid == False]) > 0:
    invalid_geom = True
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
gdf['host_name'] = 'Planet for the Planet'
gdf['url'] = 'https://web.plant-for-the-planet.org/en/' + gdf.project_id_reported
gdf['species_count_reported'] = None
gdf['species_planted_reported'] = None

gdf['project_geometries_invalid'] = invalid_geom
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
gdf.to_file('../midsave/plant_for_planet.gpkg')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
import os
import requests
import json
import sys
import time
import pathlib  # Added pathlib
from requests.auth import HTTPBasicAuth

# %%
def read_geom(file_path):
    with open(file_path) as f:
        data = json.load(f)
        if 'features' in data and data['features']:
            bbox = data['features'][0]['geometry']
            return bbox
        else:
            print(f"No features found in {file_path}. Skipping this file.")
            return None
    
def place_order(request, auth):
    response = requests.post('https://api.planet.com/compute/ops/orders/v2', data=json.dumps(request), auth=auth, headers=headers)
    print(response)
    try:
        order_id = response.json()['id']
        print(order_id)
        order_url = 'https://api.planet.com/compute/ops/orders/v2' + '/' + order_id
        return order_url
    except KeyError:
        print(f"Failed to place order for {request['name']}. ID not found.")
        return None

def poll_for_success(order_url, auth):
    while True:
        r = requests.get(order_url, auth=(api_key, ""))
        response = r.json()
        state = response['state']
        print(state)
        end_states = ['success', 'failed', 'partial']
        if state in end_states:
            break
        time.sleep(10)

def download_results(results, geojson_file, overwrite=False):
    results_urls = [r['location'] for r in results]
    results_names = [r['name'] for r in results]
    print('{} items to download'.format(len(results_urls)))
    
    # Extract the parking lot number from the GeoJSON file name
    parking_lot_number = os.path.splitext(geojson_file)[0]
    
    for url, name in zip(results_urls, results_names):
        path = pathlib.Path(os.path.join('/home/idisc02/Saarland_Forest_monitoring_research/Reforestation_Monitoring/FirstTreePlanted_new', parking_lot_number, name))
        
        if overwrite or not path.exists():
            print('downloading {} to {}'.format(name, path))
            path.parent.mkdir(parents=True, exist_ok=True)  # Create the directory if it doesn't exist
            r = requests.get(url, allow_redirects=True)
            open(path, 'wb').write(r.content)
        else:
            print('{} already exists, skipping {}'.format(path, name))

geojson_folder = '/home/idisc02/Saarland_Forest_monitoring_research/Reforestation_Monitoring/FirstTreePlanted_new'
geojson_files = [f for f in os.listdir(geojson_folder) if f.endswith('.geojson')]

# %%
API_keys = []

# %%
import os
import sys
import requests
import json
from requests.auth import HTTPBasicAuth
from datetime import datetime
from dateutil.relativedelta import relativedelta

try:
    os.environ['PL_API_KEY'] = 'PLAK731e474fdd584ac2a0ecb22def40e20d'
    api_key = os.getenv('PL_API_KEY')
except Exception as e:
    print("Failed")
    sys.exit()

headers = {'Content-Type':'application/json'}
geojson_folder = '/home/idisc02/Saarland_Forest_monitoring_research/Reforestation_Monitoring/FirstTreePlanted_new'


geojson_files = [f for f in os.listdir(geojson_folder) if f.endswith('.geojson')]


for geojson_file in geojson_files:
    print(f"Processing {geojson_file}...")
    
    geojson_path = os.path.join(geojson_folder, geojson_file)
    
    clip_aoi = read_geom(geojson_path)
    if clip_aoi is None:
        continue

 

  
    clip = {
        "clip": {
            "aoi": clip_aoi
        }
    }


    geometry_filter = {
    "type": "GeometryFilter",
    "field_name": "geometry",
    "config": clip_aoi
    }

    # Read the GeoJSON file
    with open(geojson_path, 'r') as f:
        data = json.load(f)

    # Check if 'features' exists in the data dictionary and it's not empty
    if 'features' in data and data['features']:
        # Iterate over each feature in the features list
        for feature in data['features']:
            # Check if 'properties' exists in the feature dictionary and 'FiveyearsAfterplanted' and 'OneMonthAfterFiveYears' are not None
            if 'properties' in feature and feature['properties'].get('FiveYearsAfterPlanted') and feature['properties'].get('OneMonthAfterFiveYears'):
                gte_str = feature['properties']['FiveYearsAfterPlanted'] + 'Z'
                lte_str = feature['properties']['OneMonthAfterFiveYears'] + 'Z'
                # gte_str = feature['properties']['FiveyearsAfterplanted']
                # lte_str = feature['properties']['OneMonthAfterFiveYears']

                # Use these dates in your date_range_filter
                date_range_filter = {
                    "type": "DateRangeFilter",
                    "field_name": "acquired",
                    "config": {
                        "gte": gte_str,
                        "lte": lte_str
                    }
                }
            else:
                print(f"'FiveyearsAfterplanted' or 'OneMonthAfterFiveYears' not found or is None in feature. Skipping this feature.")
                continue

            # Only get images which have <5% cloud coverage
            cloud_cover_filter = {
            "type": "RangeFilter",
            "field_name": "cloud_cover",
            "config": {
                "lt": 0.05
            }
            }

            # Combine our geometry, date, cloud filters
            combined_filter = {
            "type": "AndFilter",
            "config": [geometry_filter, date_range_filter, cloud_cover_filter]
            }

            item_type = "PSScene"
            # API request object
            search_request = {
            "item_types": [item_type], 
            "filter": combined_filter
            }

            # Fire off the POST request for searching imagery
            search_result = requests.post(
                'https://api.planet.com/data/v1/quick-search',
                auth=HTTPBasicAuth(api_key, ''),
                json=search_request)
            
            # Check the status of the response
            if search_result.status_code != 200:
                print(f"Request failed with status code {search_result.status_code}. Skipping this feature.")
                print(search_result.content)
                continue

            # Parse the search result JSON
            geojson = search_result.json()

            # Check if 'features' exists in the geojson dictionary and it's not empty
            if 'features' in geojson and geojson['features']:
                # Extract image IDs from the search results
                image_ids = [feature['id'] for feature in geojson['features']]
            else:
                print(f"No images found that match the filters. Skipping this feature.")
                continue

            # Create an order request with the clip tool and image IDs
            request = {
                "name": os.path.splitext(geojson_file)[0],  # Use the GeoJSON file name without extension
                "products": [
                    {
                        "item_ids": image_ids,
                        "item_type": "PSScene",
                        "product_bundle": "visual",
                    }
                ],
                "tools": [clip]
            }
            print(request)

            order_url = place_order(request, auth=(api_key, ""))
            if order_url is not None:
                print(order_url)
                poll_for_success(order_url, api_key)
                r = requests.get(order_url, auth=(api_key, ""))
                response = r.json()
                results = response['_links']['results']
                print(results)                                                    

                download_results(results, geojson_file)

                print(f"Processing of {geojson_file} complete.")
            else:
                print(f"Skipping download for {geojson_file} due to failed order placement.")

            #clip polygon from image use rasterio
    else:
        print(f"No features found in {geojson_file}. Skipping this file.")

print("Processing of all GeoJSON files complete.")
# Out:
# Processing geojson_proj_5hWSTz6C3pWe5hLoamlFAhZ0_113.geojson...
# No images found that match the filters. Skipping this feature.
# Processing geojson_proj_4c23gFN1xbU8xLD10qugNDkN_112.geojson...
# Request failed with status code 400. Skipping this feature.
# b'{"field": {"filter.config.0.config.coordinates.0.0": [{"message": "[76.84494814756492, 28.43572199286619, 0.0] is too long"}], "filter.config.0.config.coordinates.0.1": [{"message": "[76.84765059526147, 28.43302301097962, 0.0] is too long"}], "filter.config.0.config.coordinates.0.2": [{"message": "[76.8479802390432, 28.43309501240201, 0.0] is too long"}], "filter.config.0.config.coordinates.0.3": [{"message": "[76.8478442907547, 28.43411378884826, 0.0] is too long"}], "filter.config.0.config.coordinates.0.4": [{"message": "[76.8475555654442, 28.43416133306446, 0.0] is too long"}], "filter.config.0.config.coordinates.0.5": [{"message": "[76.84726294314358, 28.43621859576945, 0.0] is too long"}], "filter.config.0.config.coordinates.0.6": [{"message": "[76.84513586363848, 28.43602701942431, 0.0] is too long"}], "filter.config.0.config.coordinates.0.7": [{"message": "[76.84501358260039, 28.43588807084329, 0.0] is too long"}], "filter.config.0.config.coordinates.0.8": [{"message": "[76.84494814756492, 28.43572199286619, 0.0] is too long"}]}, "general": []}'
# Processing geojson_proj_4Od5ox6KBCQ6wRnnfzXgFmu4_152.geojson...
# Request failed with status code 400. Skipping this feature.
# b'{"field": {"filter.config.0.config.coordinates.0.0": [{"message": "[-0.572436640834698, 40.70217929463215, 0.0] is too long"}], "filter.config.0.config.coordinates.0.1": [{"message": "[-0.572538284088237, 40.70220376995214, 0.0] is too long"}], "filter.config.0.config.coordinates.0.10": [{"message": "[-0.574492346176238, 40.70306131587669, 0.0] is too long"}], "filter.config.0.config.coordinates.0.11": [{"message": "[-0.5745399067011581, 40.70304880899134, 0.0] is too long"}], "filter.config.0.config.coordinates.0.12": [{"message": "[-0.574614649786308, 40.70292013471825, 0.0] is too long"}], "filter.config.0.config.coordinates.0.13": [{"message": "[-0.574971106794397, 40.70265694893124, 0.0] is too long"}], "filter.config.0.config.coordinates.0.14": [{"message": "[-0.5752089320124201, 40.70251890943474, 0.0] is too long"}], "filter.config.0.config.coordinates.0.15": [{"message": "[-0.575443724877823, 40.70238260541014, 0.0] is too long"}], "filter.config.0.config.coordinates.0.16": [{"message": "[-0.575520470764171, 40.70231603328045, 0.0] is too long"}], "filter.config.0.config.coordinates.0.17": [{"message": "[-0.575590495045466, 40.70225516931826, 0.0] is too long"}], "filter.config.0.config.coordinates.0.18": [{"message": "[-0.575710141450123, 40.70215130497714, 0.0] is too long"}], "filter.config.0.config.coordinates.0.19": [{"message": "[-0.575752043226416, 40.70211192644856, 0.0] is too long"}], "filter.config.0.config.coordinates.0.2": [{"message": "[-0.5727890024747191, 40.70224183189852, 0.0] is too long"}], "filter.config.0.config.coordinates.0.20": [{"message": "[-0.575858277404386, 40.70201219380333, 0.0] is too long"}], "filter.config.0.config.coordinates.0.21": [{"message": "[-0.576037545578676, 40.70184373615998, 0.0] is too long"}], "filter.config.0.config.coordinates.0.22": [{"message": "[-0.576149177884622, 40.70173889140261, 0.0] is too long"}], "filter.config.0.config.coordinates.0.23": [{"message": "[-0.5763205326303671, 40.70157800088387, 0.0] is too long"}], "filter.config.0.config.coordinates.0.24": [{"message": "[-0.57655744483098, 40.70135555450658, 0.0] is too long"}], "filter.config.0.config.coordinates.0.25": [{"message": "[-0.5770391058944391, 40.70090313961687, 0.0] is too long"}], "filter.config.0.config.coordinates.0.26": [{"message": "[-0.5771645773182611, 40.70078534525496, 0.0] is too long"}], "filter.config.0.config.coordinates.0.27": [{"message": "[-0.577283921733252, 40.70067318148426, 0.0] is too long"}], "filter.config.0.config.coordinates.0.28": [{"message": "[-0.577378976487935, 40.70057494477517, 0.0] is too long"}], "filter.config.0.config.coordinates.0.29": [{"message": "[-0.577386593941524, 40.70056707094079, 0.0] is too long"}], "filter.config.0.config.coordinates.0.3": [{"message": "[-0.5729659914792651, 40.70228293798864, 0.0] is too long"}], "filter.config.0.config.coordinates.0.30": [{"message": "[-0.577456919241914, 40.70049450598954, 0.0] is too long"}], "filter.config.0.config.coordinates.0.31": [{"message": "[-0.577482006787364, 40.70046854621619, 0.0] is too long"}], "filter.config.0.config.coordinates.0.32": [{"message": "[-0.577490071400772, 40.70046022057994, 0.0] is too long"}], "filter.config.0.config.coordinates.0.33": [{"message": "[-0.5775277485586581, 40.70042132105154, 0.0] is too long"}], "filter.config.0.config.coordinates.0.34": [{"message": "[-0.577666823916788, 40.70027750717451, 0.0] is too long"}], "filter.config.0.config.coordinates.0.35": [{"message": "[-0.5777769894737951, 40.70016370986604, 0.0] is too long"}], "filter.config.0.config.coordinates.0.36": [{"message": "[-0.5780026184850781, 40.69993065049477, 0.0] is too long"}], "filter.config.0.config.coordinates.0.37": [{"message": "[-0.5780972947444191, 40.69983283758118, 0.0] is too long"}], "filter.config.0.config.coordinates.0.38": [{"message": "[-0.578148743354273, 40.69977500943333, 0.0] is too long"}], "filter.config.0.config.coordinates.0.39": [{"message": "[-0.5789575649592671, 40.69886 ...
# Processing geojson_proj_9YZxwGeIkwALyW2k3MQ15Fh1_226.geojson...
# No images found that match the filters. Skipping this feature.
# Processing geojson_proj_TYKEkJMw472JofF4Z4IF7ioF_234.geojson...
# Request failed with status code 400. Skipping this feature.
# b'{"field": {"filter.config.0.config.coordinates.0.0": [{"message": "[98.40361102330029, 19.28899403598946, 0.0] is too long"}], "filter.config.0.config.coordinates.0.1": [{"message": "[98.40349007528492, 19.28915578148458, 0.0] is too long"}], "filter.config.0.config.coordinates.0.10": [{"message": "[98.40221221952164, 19.28879024837432, 0.0] is too long"}], "filter.config.0.config.coordinates.0.11": [{"message": "[98.40208449347254, 19.28891532865889, 0.0] is too long"}], "filter.config.0.config.coordinates.0.12": [{"message": "[98.4019198762877, 19.28888621421867, 0.0] is too long"}], "filter.config.0.config.coordinates.0.13": [{"message": "[98.40184998389299, 19.28877454273597, 0.0] is too long"}], "filter.config.0.config.coordinates.0.14": [{"message": "[98.40178240370666, 19.28859983806828, 0.0] is too long"}], "filter.config.0.config.coordinates.0.15": [{"message": "[98.40179597535598, 19.28846006161706, 0.0] is too long"}], "filter.config.0.config.coordinates.0.16": [{"message": "[98.40177241709449, 19.28831525700097, 0.0] is too long"}], "filter.config.0.config.coordinates.0.17": [{"message": "[98.40151130861841, 19.28828903792122, 0.0] is too long"}], "filter.config.0.config.coordinates.0.18": [{"message": "[98.40141022748914, 19.2882912630186, 0.0] is too long"}], "filter.config.0.config.coordinates.0.19": [{"message": "[98.40117408057267, 19.28844562193689, 0.0] is too long"}], "filter.config.0.config.coordinates.0.2": [{"message": "[98.40335779085268, 19.28932284003302, 0.0] is too long"}], "filter.config.0.config.coordinates.0.20": [{"message": "[98.40099625530432, 19.28849072336089, 0.0] is too long"}], "filter.config.0.config.coordinates.0.21": [{"message": "[98.4008568654932, 19.28876661659586, 0.0] is too long"}], "filter.config.0.config.coordinates.0.22": [{"message": "[98.40087060211067, 19.28892958587797, 0.0] is too long"}], "filter.config.0.config.coordinates.0.23": [{"message": "[98.40096415297121, 19.28896786036304, 0.0] is too long"}], "filter.config.0.config.coordinates.0.24": [{"message": "[98.40100574987598, 19.28902902156098, 0.0] is too long"}], "filter.config.0.config.coordinates.0.25": [{"message": "[98.40095072294208, 19.28913590235936, 0.0] is too long"}], "filter.config.0.config.coordinates.0.26": [{"message": "[98.40103338340508, 19.2892508859819, 0.0] is too long"}], "filter.config.0.config.coordinates.0.27": [{"message": "[98.40085455958956, 19.2893026917136, 0.0] is too long"}], "filter.config.0.config.coordinates.0.28": [{"message": "[98.40065569544294, 19.28940966141674, 0.0] is too long"}], "filter.config.0.config.coordinates.0.29": [{"message": "[98.40050098635187, 19.28960653968798, 0.0] is too long"}], "filter.config.0.config.coordinates.0.3": [{"message": "[98.40312308147666, 19.28946677244073, 0.0] is too long"}], "filter.config.0.config.coordinates.0.30": [{"message": "[98.40044582368064, 19.28990937716588, 0.0] is too long"}], "filter.config.0.config.coordinates.0.31": [{"message": "[98.4002749434102, 19.28987931875744, 0.0] is too long"}], "filter.config.0.config.coordinates.0.32": [{"message": "[98.40006592314178, 19.28979487080764, 0.0] is too long"}], "filter.config.0.config.coordinates.0.33": [{"message": "[98.3996200482785, 19.28974667806436, 0.0] is too long"}], "filter.config.0.config.coordinates.0.34": [{"message": "[98.39963636612818, 19.28959061358159, 0.0] is too long"}], "filter.config.0.config.coordinates.0.35": [{"message": "[98.39974403289808, 19.28950286958392, 0.0] is too long"}], "filter.config.0.config.coordinates.0.36": [{"message": "[98.39999706489975, 19.28941899465612, 0.0] is too long"}], "filter.config.0.config.coordinates.0.37": [{"message": "[98.40029448208475, 19.28930082745897, 0.0] is too long"}], "filter.config.0.config.coordinates.0.38": [{"message": "[98.40043283769045, 19.28903669009635, 0.0] is too long"}], "filter.config.0.config.coordinates.0.39": [{"message": "[98.40055746939709, 19.28869318507132, 0.0] is too long"}], "filter.config.0.con ...
# Processing geojson_proj_qbi1Nb9ZuPcQdJ39xD0FXmQy_213.geojson...
# Request failed with status code 400. Skipping this feature.
# b'{"field": {"filter.config.0.config.coordinates.0.0": [{"message": "[-118.4129601, 44.2054351, 0.0] is too long"}], "filter.config.0.config.coordinates.0.1": [{"message": "[-118.4123164, 44.2034046, 0.0] is too long"}], "filter.config.0.config.coordinates.0.2": [{"message": "[-118.4112006, 44.2035739, 0.0] is too long"}], "filter.config.0.config.coordinates.0.3": [{"message": "[-118.411501, 44.2052351, 0.0] is too long"}], "filter.config.0.config.coordinates.0.4": [{"message": "[-118.4129601, 44.2054351, 0.0] is too long"}]}, "general": []}'
# Processing geojson_proj_SuKA0nlGqbv4PZib0xnaoUSs_126.geojson...
# No images found that match the filters. Skipping this feature.
# Processing geojson_proj_7gmlF7Q8aL65V7j7AG9NW8Yy_227.geojson...
# Request failed with status code 400. Skipping this feature.
# b'{"field": {"filter.config.0.config.coordinates.0.0": [{"message": "[-83.20346101151264, 8.925236730112783, 0.0] is too long"}], "filter.config.0.config.coordinates.0.1": [{"message": "[-83.20449395539652, 8.924958918223618, 0.0] is too long"}], "filter.config.0.config.coordinates.0.10": [{"message": "[-83.20771026685351, 8.91769781261566, 0.0] is too long"}], "filter.config.0.config.coordinates.0.11": [{"message": "[-83.2069906073362, 8.916898300272468, 0.0] is too long"}], "filter.config.0.config.coordinates.0.12": [{"message": "[-83.20646597463598, 8.916304710635448, 0.0] is too long"}], "filter.config.0.config.coordinates.0.13": [{"message": "[-83.20593034102507, 8.916091218906942, 0.0] is too long"}], "filter.config.0.config.coordinates.0.14": [{"message": "[-83.20457708580729, 8.915402964796531, 0.0] is too long"}], "filter.config.0.config.coordinates.0.15": [{"message": "[-83.20376046565596, 8.915991943624011, 0.0] is too long"}], "filter.config.0.config.coordinates.0.16": [{"message": "[-83.20360092798693, 8.916484123507818, 0.0] is too long"}], "filter.config.0.config.coordinates.0.17": [{"message": "[-83.20333251615422, 8.917285632135833, 0.0] is too long"}], "filter.config.0.config.coordinates.0.18": [{"message": "[-83.20320297630879, 8.91796103455921, 0.0] is too long"}], "filter.config.0.config.coordinates.0.19": [{"message": "[-83.20319478850364, 8.918543362766739, 0.0] is too long"}], "filter.config.0.config.coordinates.0.2": [{"message": "[-83.20532176711595, 8.92445183923527, 0.0] is too long"}], "filter.config.0.config.coordinates.0.20": [{"message": "[-83.20322218148705, 8.919255053406658, 0.0] is too long"}], "filter.config.0.config.coordinates.0.21": [{"message": "[-83.20333798669617, 8.919790776607393, 0.0] is too long"}], "filter.config.0.config.coordinates.0.22": [{"message": "[-83.20366366161984, 8.920555207879932, 0.0] is too long"}], "filter.config.0.config.coordinates.0.23": [{"message": "[-83.203775368115, 8.92103897506963, 0.0] is too long"}], "filter.config.0.config.coordinates.0.24": [{"message": "[-83.20355891205375, 8.921319919124036, 0.0] is too long"}], "filter.config.0.config.coordinates.0.25": [{"message": "[-83.20335836742527, 8.921632020422935, 0.0] is too long"}], "filter.config.0.config.coordinates.0.26": [{"message": "[-83.20300055864793, 8.922359781190387, 0.0] is too long"}], "filter.config.0.config.coordinates.0.27": [{"message": "[-83.20254618736163, 8.923555105734053, 0.0] is too long"}], "filter.config.0.config.coordinates.0.28": [{"message": "[-83.2023071298857, 8.924230949578472, 0.0] is too long"}], "filter.config.0.config.coordinates.0.29": [{"message": "[-83.20346101151264, 8.925236730112783, 0.0] is too long"}], "filter.config.0.config.coordinates.0.3": [{"message": "[-83.2063124854859, 8.923317241380836, 0.0] is too long"}], "filter.config.0.config.coordinates.0.4": [{"message": "[-83.20671271597651, 8.922002783850655, 0.0] is too long"}], "filter.config.0.config.coordinates.0.5": [{"message": "[-83.20687568858528, 8.921056486506512, 0.0] is too long"}], "filter.config.0.config.coordinates.0.6": [{"message": "[-83.2073441093387, 8.920987762633901, 0.0] is too long"}], "filter.config.0.config.coordinates.0.7": [{"message": "[-83.20860618384255, 8.920267555562553, 0.0] is too long"}], "filter.config.0.config.coordinates.0.8": [{"message": "[-83.20871113736982, 8.918673588242873, 0.0] is too long"}], "filter.config.0.config.coordinates.0.9": [{"message": "[-83.20806640683988, 8.918157680346178, 0.0] is too long"}]}, "general": []}'
# Processing geojson_proj_H11x6rzD9PQchjy90SjEcNsu_143.geojson...
# Request failed with status code 400. Skipping this feature.
# b'{"field": {"filter.config.0.config.coordinates.0.0": [{"message": "[-5.607608264668262, 36.39816222150115, 0.0] is too long"}], "filter.config.0.config.coordinates.0.1": [{"message": "[-5.607061463563095, 36.39821708899968, 0.0] is too long"}], "filter.config.0.config.coordinates.0.10": [{"message": "[-5.60586281666965, 36.40392332943893, 0.0] is too long"}], "filter.config.0.config.coordinates.0.11": [{"message": "[-5.604718201089395, 36.40462792050354, 0.0] is too long"}], "filter.config.0.config.coordinates.0.12": [{"message": "[-5.60368663101129, 36.40500811669253, 0.0] is too long"}], "filter.config.0.config.coordinates.0.13": [{"message": "[-5.60300520502468, 36.40527336170479, 0.0] is too long"}], "filter.config.0.config.coordinates.0.14": [{"message": "[-5.602558424516608, 36.40647062538304, 0.0] is too long"}], "filter.config.0.config.coordinates.0.15": [{"message": "[-5.602684095052414, 36.4073191790322, 0.0] is too long"}], "filter.config.0.config.coordinates.0.16": [{"message": "[-5.603274943056774, 36.40725621592382, 0.0] is too long"}], "filter.config.0.config.coordinates.0.17": [{"message": "[-5.603770909766597, 36.40700216928192, 0.0] is too long"}], "filter.config.0.config.coordinates.0.18": [{"message": "[-5.604108645266583, 36.40678018831342, 0.0] is too long"}], "filter.config.0.config.coordinates.0.19": [{"message": "[-5.60468609861474, 36.4068462777096, 0.0] is too long"}], "filter.config.0.config.coordinates.0.2": [{"message": "[-5.606282352463854, 36.3989995543197, 0.0] is too long"}], "filter.config.0.config.coordinates.0.20": [{"message": "[-5.604969067190769, 36.40763416544187, 0.0] is too long"}], "filter.config.0.config.coordinates.0.21": [{"message": "[-5.606079535422139, 36.40749546159857, 0.0] is too long"}], "filter.config.0.config.coordinates.0.22": [{"message": "[-5.6059908694812925, 36.40696086822395, 0.0] is too long"}], "filter.config.0.config.coordinates.0.23": [{"message": "[-5.606450026095896, 36.40587062829372, 0.0] is too long"}], "filter.config.0.config.coordinates.0.24": [{"message": "[-5.607368780349331, 36.40582194445495, 0.0] is too long"}], "filter.config.0.config.coordinates.0.25": [{"message": "[-5.607725378360784, 36.40484124639809, 0.0] is too long"}], "filter.config.0.config.coordinates.0.26": [{"message": "[-5.608073603079395, 36.40387503774608, 0.0] is too long"}], "filter.config.0.config.coordinates.0.27": [{"message": "[-5.607992577035626, 36.40330451018849, 0.0] is too long"}], "filter.config.0.config.coordinates.0.28": [{"message": "[-5.60809223739088, 36.4028444937853, 0.0] is too long"}], "filter.config.0.config.coordinates.0.29": [{"message": "[-5.607685696944179, 36.40259584292981, 0.0] is too long"}], "filter.config.0.config.coordinates.0.3": [{"message": "[-5.6060918755680476, 36.39912532706114, 0.0] is too long"}], "filter.config.0.config.coordinates.0.30": [{"message": "[-5.607158943289634, 36.40219243467778, 0.0] is too long"}], "filter.config.0.config.coordinates.0.31": [{"message": "[-5.606809053234485, 36.4017851610783, 0.0] is too long"}], "filter.config.0.config.coordinates.0.32": [{"message": "[-5.60704781546751, 36.40125056974425, 0.0] is too long"}], "filter.config.0.config.coordinates.0.33": [{"message": "[-5.607287051334757, 36.40099496312154, 0.0] is too long"}], "filter.config.0.config.coordinates.0.34": [{"message": "[-5.607053556035168, 36.40062806971205, 0.0] is too long"}], "filter.config.0.config.coordinates.0.35": [{"message": "[-5.6070977738179195, 36.40009772766431, 0.0] is too long"}], "filter.config.0.config.coordinates.0.36": [{"message": "[-5.607006962158719, 36.39949879776781, 0.0] is too long"}], "filter.config.0.config.coordinates.0.37": [{"message": "[-5.607087745073632, 36.39900342562424, 0.0] is too long"}], "filter.config.0.config.coordinates.0.38": [{"message": "[-5.607525812874264, 36.39860755430642, 0.0] is too long"}], "filter.config.0.config.coordinates.0.39": [{"message": "[-5.607608264668262, 36.39816222150115, 0.0] is  ...
# Processing geojson_proj_7l7Wn23bOs5bwVftjSshnkh2_173.geojson...
# Request failed with status code 400. Skipping this feature.
# b'{"field": {"filter.config.0.config.coordinates.0.0": [{"message": "[-105.8945606999999, 37.49669230000006, 0.0] is too long"}], "filter.config.0.config.coordinates.0.1": [{"message": "[-105.8943354, 37.49710090000008, 0.0] is too long"}], "filter.config.0.config.coordinates.0.10": [{"message": "[-105.8914601, 37.49815640000003, 0.0] is too long"}], "filter.config.0.config.coordinates.0.11": [{"message": "[-105.8909451, 37.49815640000003, 0.0] is too long"}], "filter.config.0.config.coordinates.0.12": [{"message": "[-105.8906125, 37.49833520000004, 0.0] is too long"}], "filter.config.0.config.coordinates.0.13": [{"message": "[-105.8903979999999, 37.49860750000005, 0.0] is too long"}], "filter.config.0.config.coordinates.0.14": [{"message": "[-105.8903549999999, 37.49893100000003, 0.0] is too long"}], "filter.config.0.config.coordinates.0.15": [{"message": "[-105.8904194, 37.49938210000005, 0.0] is too long"}], "filter.config.0.config.coordinates.0.16": [{"message": "[-105.8909558999999, 37.49936510000003, 0.0] is too long"}], "filter.config.0.config.coordinates.0.17": [{"message": "[-105.8908486, 37.49915230000005, 0.0] is too long"}], "filter.config.0.config.coordinates.0.18": [{"message": "[-105.8908486, 37.49876080000007, 0.0] is too long"}], "filter.config.0.config.coordinates.0.19": [{"message": "[-105.8910630999999, 37.49864160000004, 0.0] is too long"}], "filter.config.0.config.coordinates.0.2": [{"message": "[-105.8940458, 37.49722860000003, 0.0] is too long"}], "filter.config.0.config.coordinates.0.20": [{"message": "[-105.8918571, 37.49842880000006, 0.0] is too long"}], "filter.config.0.config.coordinates.0.21": [{"message": "[-105.8920824, 37.49808830000006, 0.0] is too long"}], "filter.config.0.config.coordinates.0.22": [{"message": "[-105.8923184, 37.49767120000007, 0.0] is too long"}], "filter.config.0.config.coordinates.0.23": [{"message": "[-105.8927583, 37.49750100000006, 0.0] is too long"}], "filter.config.0.config.coordinates.0.24": [{"message": "[-105.8933054999999, 37.49757760000006, 0.0] is too long"}], "filter.config.0.config.coordinates.0.25": [{"message": "[-105.8938204, 37.49762020000003, 0.0] is too long"}], "filter.config.0.config.coordinates.0.26": [{"message": "[-105.8943998, 37.49749250000008, 0.0] is too long"}], "filter.config.0.config.coordinates.0.27": [{"message": "[-105.8947002, 37.49722010000005, 0.0] is too long"}], "filter.config.0.config.coordinates.0.28": [{"message": "[-105.8948503999999, 37.49680300000006, 0.0] is too long"}], "filter.config.0.config.coordinates.0.29": [{"message": "[-105.8945606999999, 37.49669230000006, 0.0] is too long"}], "filter.config.0.config.coordinates.0.3": [{"message": "[-105.893681, 37.49722860000003, 0.0] is too long"}], "filter.config.0.config.coordinates.0.4": [{"message": "[-105.8932411, 37.49718600000006, 0.0] is too long"}], "filter.config.0.config.coordinates.0.5": [{"message": "[-105.8928334, 37.49711790000003, 0.0] is too long"}], "filter.config.0.config.coordinates.0.6": [{"message": "[-105.8922755, 37.49720310000004, 0.0] is too long"}], "filter.config.0.config.coordinates.0.7": [{"message": "[-105.8919964999999, 37.49735630000004, 0.0] is too long"}], "filter.config.0.config.coordinates.0.8": [{"message": "[-105.8918141999999, 37.49765420000006, 0.0] is too long"}], "filter.config.0.config.coordinates.0.9": [{"message": "[-105.891664, 37.49801170000006, 0.0] is too long"}]}, "general": []}'
# Processing geojson_proj_3aQZi1SCNWqqmM8duObtYchF_182.geojson...
# Request failed with status code 400. Skipping this feature.
# b'{"field": {"filter.config.0.config.coordinates.0.0": [{"message": "[153.478637294447, -28.64043501073701, 0.0] is too long"}], "filter.config.0.config.coordinates.0.1": [{"message": "[153.4787813129837, -28.64044132842753, 0.0] is too long"}], "filter.config.0.config.coordinates.0.10": [{"message": "[153.4793734272921, -28.63998565578894, 0.0] is too long"}], "filter.config.0.config.coordinates.0.100": [{"message": "[153.4812101839874, -28.63823844503952, 0.0] is too long"}], "filter.config.0.config.coordinates.0.101": [{"message": "[153.4812219934203, -28.63833251266013, 0.0] is too long"}], "filter.config.0.config.coordinates.0.102": [{"message": "[153.4813388411187, -28.63831372714326, 0.0] is too long"}], "filter.config.0.config.coordinates.0.103": [{"message": "[153.4813449809596, -28.63831447428485, 0.0] is too long"}], "filter.config.0.config.coordinates.0.104": [{"message": "[153.4813757536586, -28.63831160878443, 0.0] is too long"}], "filter.config.0.config.coordinates.0.105": [{"message": "[153.4815169704535, -28.63832879385684, 0.0] is too long"}], "filter.config.0.config.coordinates.0.106": [{"message": "[153.4815476642288, -28.63833252902451, 0.0] is too long"}], "filter.config.0.config.coordinates.0.107": [{"message": "[153.4816886714162, -28.63835629607713, 0.0] is too long"}], "filter.config.0.config.coordinates.0.108": [{"message": "[153.4817264814737, -28.63832119946786, 0.0] is too long"}], "filter.config.0.config.coordinates.0.109": [{"message": "[153.4817268159636, -28.63830798009769, 0.0] is too long"}], "filter.config.0.config.coordinates.0.11": [{"message": "[153.4795114310633, -28.63993399597787, 0.0] is too long"}], "filter.config.0.config.coordinates.0.110": [{"message": "[153.4817603688425, -28.63820548815587, 0.0] is too long"}], "filter.config.0.config.coordinates.0.111": [{"message": "[153.481748718305, -28.63817728430929, 0.0] is too long"}], "filter.config.0.config.coordinates.0.112": [{"message": "[153.4817372143853, -28.63814232241102, 0.0] is too long"}], "filter.config.0.config.coordinates.0.113": [{"message": "[153.4817315356151, -28.63812145178077, 0.0] is too long"}], "filter.config.0.config.coordinates.0.114": [{"message": "[153.4816908917861, -28.63800154343496, 0.0] is too long"}], "filter.config.0.config.coordinates.0.115": [{"message": "[153.481678919995, -28.63797968892811, 0.0] is too long"}], "filter.config.0.config.coordinates.0.116": [{"message": "[153.4816673906067, -28.63793739753734, 0.0] is too long"}], "filter.config.0.config.coordinates.0.117": [{"message": "[153.4816328718314, -28.63779595478755, 0.0] is too long"}], "filter.config.0.config.coordinates.0.118": [{"message": "[153.4816274677391, -28.63775384061715, 0.0] is too long"}], "filter.config.0.config.coordinates.0.119": [{"message": "[153.4816221893123, -28.63770466447217, 0.0] is too long"}], "filter.config.0.config.coordinates.0.12": [{"message": "[153.4795339266706, -28.63993099050379, 0.0] is too long"}], "filter.config.0.config.coordinates.0.120": [{"message": "[153.4816194629115, -28.6375295176647, 0.0] is too long"}], "filter.config.0.config.coordinates.0.121": [{"message": "[153.4816200377427, -28.63750139996195, 0.0] is too long"}], "filter.config.0.config.coordinates.0.122": [{"message": "[153.4816144090269, -28.63746538888823, 0.0] is too long"}], "filter.config.0.config.coordinates.0.123": [{"message": "[153.4815660747183, -28.63732436282092, 0.0] is too long"}], "filter.config.0.config.coordinates.0.124": [{"message": "[153.4815538171587, -28.63729423825882, 0.0] is too long"}], "filter.config.0.config.coordinates.0.125": [{"message": "[153.4815414088728, -28.63727120863873, 0.0] is too long"}], "filter.config.0.config.coordinates.0.126": [{"message": "[153.4815166481685, -28.63721784956075, 0.0] is too long"}], "filter.config.0.config.coordinates.0.127": [{"message": "[153.4814606116195, -28.63709522257525, 0.0] is too long"}], "filter.config.0.config.coordinates.0.128": [{"message": "[153.48144803 ...
# Processing geojson_proj_COg1GB1X0cqzZk0N1VSdZBYi_225.geojson...
# {'name': 'geojson_proj_COg1GB1X0cqzZk0N1VSdZBYi_225', 'products': [{'item_ids': ['20200917_083009_51_241c', '20200917_063115_0f2b', '20200917_063114_0f2b', '20200917_080406_1003', '20201011_073617_86_2223', '20201005_083622_31_105e', '20200930_080131_1011'], 'item_type': 'PSScene', 'product_bundle': 'visual'}], 'tools': [{'clip': {'aoi': {'type': 'Polygon', 'coordinates': [[
z', 'location': 'https://api.planet.com/compute/ops/download/?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9.....ZWs4QtsIJj2lF-nOcFXvlrxKfw34q8WuPzup0RrKH-wbZ4RA2a7pCo5DyOA8WBhbFJ9UEc-eaIQzN5u6gNfPjA', 'name': 'f896363b-30d2-4d10-b536-109e52475b7f/PSScene/20221017_110056_78_2485_metadata.json'}, {'delivery': 'success', 'expires_at': '2024-03-08T18:27:06.900Z', 'location': 'https://api.planet.com/compute/ops/download/?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9...._....M0eF64yoWTQL8VkhtJtnY6w0IcFhfTomsap8yKMTeYw9ruGqYvJ6KvqmpdeUGEpfxTywo3tu_ClaFzxb5DD7VA', 'name': 'f896363b-30d2-4d10-b536-109e52475b7f/PSScene/20221017_110056_78_2485_3B_Visual_clip.tif'}, {'delivery': 'success', 'expires_at': '2024-03-08T18:27:06.897Z', 'location': 'https://api.planet.com/compute/ops/download/?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9.....HKUcQjNbyFPL7RSRGG1YADDHdt3MlUHBGv0R-DMhzjqR8zp69U1O5wuYhG9dN4ubsWIx89RUzGAwngYw81rsCw', 'name': 'f896363b-30d2-4d10-b536-109e52475b7f/manifest.json'}]
# 3 items to download
# downloading f896363b-30d2-4d10-b536-109e52475b7f/PSScene/20221017_110056_78_2485_metadata.json to /home/idisc02/Saarland_Forest_monitoring_research/Reforestation_Monitoring/FirstTreePlanted_new/geojson_proj_4oMbRLlboiwsD65NLmBSVOOo_166/f896363b-30d2-4d10-b536-109e52475b7f/PSScene/20221017_110056_78_2485_metadata.json
# downloading f896363b-30d2-4d10-b536-109e52475b7f/PSScene/20221017_110056_78_2485_3B_Visual_clip.tif to /home/idisc02/Saarland_Forest_monitoring_research/Reforestation_Monitoring/FirstTreePlanted_new/geojson_proj_4oMbRLlboiwsD65NLmBSVOOo_166/f896363b-30d2-4d10-b536-109e52475b7f/PSScene/20221017_110056_78_2485_3B_Visual_clip.tif
# downloading f896363b-30d2-4d10-b536-109e52475b7f/manifest.json to /home/idisc02/Saarland_Forest_monitoring_research/Reforestation_Monitoring/FirstTreePlanted_new/geojson_proj_4oMbRLlboiwsD65NLmBSVOOo_166/f896363b-30d2-4d10-b536-109e52475b7f/manifest.json
# Processing of geojson_proj_4oMbRLlboiwsD65NLmBSVOOo_166.geojson complete.
# Processing geojson_proj_LMEDcuo62mrVMyEVmfes1g4h_172.geojson...
# Request failed with status code 400. Skipping this feature.
# b'{"field": {"filter.config.0.config.coordinates.0.0": [{"message": "[33.44064811073788, -13.31124732229188, 0.0] is too long"}], "filter.config.0.config.coordinates.0.1": [{"message": "[33.44100413375719, -13.3107733293161, 0.0] is too long"}], "filter.config.0.config.coordinates.0.10": [{"message": "[33.43966199682478, -13.30914287043864, 0.0] is too long"}], "filter.config.0.config.coordinates.0.11": [{"message": "[33.43994463063907, -13.30986046753802, 0.0] is too long"}], "filter.config.0.config.coordinates.0.12": [{"message": "[33.44035719419701, -13.3104549730247, 0.0] is too long"}], "filter.config.0.config.coordinates.0.13": [{"message": "[33.44003035037208, -13.31100305435394, 0.0] is too long"}], "filter.config.0.config.coordinates.0.14": [{"message": "[33.44064811073788, -13.31124732229188, 0.0] is too long"}], "filter.config.0.config.coordinates.0.2": [{"message": "[33.44152531426332, -13.31024559130775, 0.0] is too long"}], "filter.config.0.config.coordinates.0.3": [{"message": "[33.44231967354919, -13.30951351274793, 0.0] is too long"}], "filter.config.0.config.coordinates.0.4": [{"message": "[33.44100859050274, -13.30824588284716, 0.0] is too long"}], "filter.config.0.config.coordinates.0.5": [{"message": "[33.44035254865284, -13.30816859391034, 0.0] is too long"}], "filter.config.0.config.coordinates.0.6": [{"message": "[33.44008082604984, -13.30779899699937, 0.0] is too long"}], "filter.config.0.config.coordinates.0.7": [{"message": "[33.43939480876136, -13.30744015725406, 0.0] is too long"}], "filter.config.0.config.coordinates.0.8": [{"message": "[33.43861455494151, -13.30652947849186, 0.0] is too long"}], "filter.config.0.config.coordinates.0.9": [{"message": "[33.43814540795759, -13.30715364348773, 0.0] is too long"}]}, "general": []}'
# Processing geojson_proj_skIGjRcczH5EMWhYPDb2bMYX_107.geojson...
# Request failed with status code 400. Skipping this feature.
# b'{"field": {"filter.config.0.config.coordinates.0.0": [{"message": "[103.4555258, 15.2436384, 0.0] is too long"}], "filter.config.0.config.coordinates.0.1": [{"message": "[103.4555978, 15.2435492, 0.0] is too long"}], "filter.config.0.config.coordinates.0.2": [{"message": "[103.4557802, 15.2435608, 0.0] is too long"}], "filter.config.0.config.coordinates.0.3": [{"message": "[103.4560689, 15.2437601, 0.0] is too long"}], "filter.config.0.config.coordinates.0.4": [{"message": "[103.4560403, 15.2438177, 0.0] is too long"}], "filter.config.0.config.coordinates.0.5": [{"message": "[103.4555258, 15.2436384, 0.0] is too long"}]}, "general": []}'
# Processing geojson_proj_E2WkRdczL4HiBBs4TBogTn9M_220.geojson...
# No images found that match the filters. Skipping this feature.
# Processing of all GeoJSON files complete.
